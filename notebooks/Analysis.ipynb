# %%
import blocksci
import collections
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt


parser_data_directory = Path("/mnt/anal/config.json")
cluster_directory = Path("/mnt/anal/cluster/")
dumplings_directory = Path("/mnt/dumplings/")

chain = blocksci.Blockchain(str(parser_data_directory))

print("\nScanning for potential CoinJoin-like transactions (large Txes)...")
large_txs = [tx for block in chain for tx in block.txes if tx.inputs.count > 20 and tx.outputs.count > 20]
print(f"Found {len(large_txs)} transactions with >10 inputs and >10 outputs.")

# Try the explicit name used in the extension
try:
    print("Running WW2 CoinJoin detection...")
    # Using 0 to len(chain) to scan all regtest blocks
    ww2_coinjoins = list(chain.filter_coinjoin_txes(0, len(chain), "wasabi2"))
    
    print(f"Success! Detected {len(ww2_coinjoins)} Wasabi 2 transactions in regtest.")
    
except Exception as e:
    print(f"Detection failed: {e}")

from typing import Tuple

def get_block_height_for_date(date: str) -> int:
    return chain.range(date)[0].height

def get_block_height_range(start: str, end: str) -> Tuple[int, int]:
    return get_block_height_for_date(start), get_block_height_for_date(end)

print(f"loaded chain with {len(chain)} blocks, last block is from {chain.blocks[-1].time}")

import json

# Open and read the raw config file that BlockSci uses
with open(parser_data_directory, 'r') as f:
    config_data = json.load(f)

# Print the configuration to see what the C++ backend is loading
print(json.dumps(config_data, indent=4))


# 1. Let's brute-force the expected C++ string identifier
test_strings = ["ww2", "WW2", "wasabi2", "Wasabi2", "wasabi_2", "wasabi"]

print("Testing different CoinJoin type identifiers...")
for cj_type in test_strings:
    try:
        txs = list(chain.filter_coinjoin_txes(0, len(chain), cj_type))
        if txs:
            print(f"Bingo! Detected {len(txs)} transactions using the string: '{cj_type}'")
            break
    except Exception:
        # Ignore errors for unsupported strings
        pass
else:
    print("No transactions found with any of the tested strings.")

# 2. Let's check for ANY large transactions to see if the heuristic is rejecting them
print("\nScanning for potential CoinJoin-like transactions (large Txes)...")
large_txs = [tx for block in chain for tx in block.txes if tx.inputs.count > 10 and tx.outputs.count > 10]
print(f"Found {len(large_txs)} transactions with >10 inputs and >10 outputs.")





import collections

# We already have your large_txs list from the previous step
for i, tx in enumerate(large_txs):
    print(f"\n--- Suspected CoinJoin {i+1} ---")
    print(f"Block Height: {tx.block.height}")
    print(f"Tx Hash: {tx.hash}")
    print(f"Inputs: {tx.input_count} | Outputs: {tx.output_count}")
    
    # Extract all output values (in satoshis)
    out_values = [out.value for out in tx.outputs]
    
    # Count how many times each value appears
    value_counts = collections.Counter(out_values)
    
    # Calculate how many outputs share a value with at least one other output
    # (A very rough proxy for "standard denominations" in a coinjoin)
    shared_outputs = sum(count for val, count in value_counts.items() if count > 1)
    shared_percentage = (shared_outputs / tx.output_count) * 100
    
    print(f"Outputs sharing a value with another output: {shared_percentage:.1f}%")
    
    print("Most common output denominations (Satoshis -> Count):")
    for val, count in value_counts.most_common(5):
        pct = (count / tx.output_count) * 100
        print(f"  {val} sats : {count} outputs ({pct:.1f}%)")



print("Testing with overridden min_input_count...")

# We will test the most likely C++ internal strings
test_strings = ["wasabi2", "ww2", "wasabi_2", "Wasabi2", "wabisabi"]

for cj_type in test_strings:
    try:
        # Notice the '10' at the end - this overrides the minimum input threshold
        txs = list(chain.filter_coinjoin_txes(0, len(chain), cj_type, 1))
        if txs:
            print(f"Success! Detected {len(txs)} txs using string '{cj_type}' with min_inputs=10")
            # Break out of the loop once we find the correct string
            break
    except Exception as e:
        # Ignore unsupported string errors
        pass
else:
    print("Still no transactions found. The heuristic might be failing on Script Types (SegWit/Taproot).")



import collections

# Using the large_txs list we found earlier
for i, tx in enumerate(large_txs):
    print(f"\n--- Suspected CoinJoin {i+1} ({tx.hash}) ---")
    
    # Check input address types
    in_types = collections.Counter([inp.address_type.name for inp in tx.inputs])
    print("Input Types:")
    for addr_type, count in in_types.items():
        print(f"  {addr_type}: {count}")
        
    # Check output address types
    out_types = collections.Counter([out.address_type.name for out in tx.outputs])
    print("Output Types:")
    for addr_type, count in out_types.items():
        print(f"  {addr_type}: {count}")


# Check if the outputs are strictly descending
for i, tx in enumerate(large_txs):
    out_values = [out.value for out in tx.outputs]
    
    # Check if every value is less than or equal to the previous one
    is_descending = all(out_values[j] >= out_values[j+1] for j in range(len(out_values)-1))
    
    print(f"\n--- Suspected CoinJoin {i+1} ---")
    print(f"Sorted strictly descending? {is_descending}")
    
    if not is_descending:
        print("First 5 output values to show the order:")
        print(f"  {out_values[:5]}")

    for i, tx in enumerate(large_txs):
        # Using a set to automatically filter out duplicate addresses
        unique_addresses = set(out.address for out in tx.outputs)
        
        print(f"--- Suspected CoinJoin {i+1} ---")
        print(f"Total Outputs: {tx.output_count}")
        print(f"Unique Addresses: {len(unique_addresses)}")
        
        if len(unique_addresses) < 5:
            print("🚨 FAILED the C++ unique address check (< 5)!")
        else:
            print("✅ Passed the C++ unique address check.")
# Out:
# Scanning for potential CoinJoin-like transactions (large Txes)...
# Found 23 transactions with >10 inputs and >10 outputs.
# Running WW2 CoinJoin detection...
# Success! Detected 16 Wasabi 2 transactions in regtest.
# loaded chain with 840 blocks, last block is from 2026-04-16 00:10:07
# {
#     "chainConfig": {
#         "coinJoinConfiguration": {
#             "FirstSamouraiBlock": 0,
#             "FirstWasabi2Block": 0,
#             "FirstWasabiBlock": 0,
#             "FirstWasabiNoCoordAddressBlock": 0
#         },
#         "coinName": "bitcoin_regtest",
#         "dataDirectory": "/mnt/anal/blocksci_data",
#         "pubkeyPrefix": [
#             111
#         ],
#         "scriptPrefix": [
#             196
#         ],
#         "segwitActivationHeight": 0,
#         "segwitPrefix": "bcrt"
#     },
#     "parser": {
#         "disk": {
#             "blockMagic": 3669344250,
#             "coinDirectory": "/mnt/data/regtest",
#             "hashFuncName": "doubleSha256"
#         },
#         "maxBlockNum": 3000000
#     },
#     "version": 5
# }
# Testing different CoinJoin type identifiers...
# Bingo! Detected 16 transactions using the string: 'wasabi2'
#
# Scanning for potential CoinJoin-like transactions (large Txes)...
# Found 44 transactions with >10 inputs and >10 outputs.
#
# --- Suspected CoinJoin 1 ---
# Block Height: 230
# Tx Hash: bafdc4a656d7506801ad688eac63c07518481967ba160a205087156bf47f9bbd
# Inputs: 15 | Outputs: 56
# Outputs sharing a value with another output: 89.3%
# Most common output denominations (Satoshis -> Count):
#   1062882 sats : 10 outputs (17.9%)
#   5000000 sats : 7 outputs (12.5%)
#   2097152 sats : 7 outputs (12.5%)
#   500000 sats : 6 outputs (10.7%)
#   20000 sats : 5 outputs (8.9%)
#
# --- Suspected CoinJoin 2 ---
# Block Height: 245
# Tx Hash: 8061a947455a7c0ea54dcc7e4af1c4062f1b26ac3a0a0c3c1a2f1b52c68794a4
# Inputs: 33 | Outputs: 67
# Outputs sharing a value with another output: 97.0%
# Most common output denominations (Satoshis -> Count):
#   5000000 sats : 10 outputs (14.9%)
#   354294 sats : 9 outputs (13.4%)
#   2097152 sats : 7 outputs (10.4%)
#   531441 sats : 6 outputs (9.0%)
#   16384 sats : 5 outputs (7.5%)
#
# --- Suspected CoinJoin 3 ---
# Block Height: 256
# Tx Hash: 1c21ea259bafabccbf7e3b047935237da7d035f17e1290b4da1910cc4e79e8a8
# Inputs: 47 | Outputs: 66
# Outputs sharing a value with another output: 93.9%
# Most common output denominations (Satoshis -> Count):
#   5000000 sats : 11 outputs (16.7%)
#   2097152 sats : 7 outputs (10.6%)
#   200000 sats : 6 outputs (9.1%)
#   20000 sats : 6 outputs (9.1%)
#   8388608 sats : 5 outputs (7.6%)
#
# --- Suspected CoinJoin 4 ---
# Block Height: 267
# Tx Hash: eb738a391cfcce73da85c1857a9717ae3b8d12dfd5d43550ae592876622c5de5
# Inputs: 47 | Outputs: 56
# Outputs sharing a value with another output: 94.6%
# Most common output denominations (Satoshis -> Count):
#   5000000 sats : 7 outputs (12.5%)
#   262144 sats : 6 outputs (10.7%)
#   2000000 sats : 5 outputs (8.9%)
#   1062882 sats : 5 outputs (8.9%)
#   3188646 sats : 4 outputs (7.1%)
#
# --- Suspected CoinJoin 5 ---
# Block Height: 282
# Tx Hash: 5897a02d02cbf55fc3f92b40f9026f4c9425e28b08d4424edcdb60003956837b
# Inputs: 59 | Outputs: 72
# Outputs sharing a value with another output: 97.2%
# Most common output denominations (Satoshis -> Count):
#   5000000 sats : 17 outputs (23.6%)
#   2097152 sats : 9 outputs (12.5%)
#   39366 sats : 7 outputs (9.7%)
#   3188646 sats : 5 outputs (6.9%)
#   1062882 sats : 5 outputs (6.9%)
#
# --- Suspected CoinJoin 6 ---
# Block Height: 295
# Tx Hash: 49ace62f4ad8c584e88e6a0908c039ddc548c70b0e1242f7c1f9cd14924b9141
# Inputs: 59 | Outputs: 63
# Outputs sharing a value with another output: 96.8%
# Most common output denominations (Satoshis -> Count):
#   1062882 sats : 10 outputs (15.9%)
#   4782969 sats : 9 outputs (14.3%)
#   2097152 sats : 9 outputs (14.3%)
#   200000 sats : 8 outputs (12.7%)
#   354294 sats : 6 outputs (9.5%)
#
# --- Suspected CoinJoin 7 ---
# Block Height: 309
# Tx Hash: 50f0a89799a4bc5e18b124500e887e630fd10284778dbd27e77ebc3960daba7d
# Inputs: 58 | Outputs: 64
# Outputs sharing a value with another output: 93.8%
# Most common output denominations (Satoshis -> Count):
#   2097152 sats : 17 outputs (26.6%)
#   5000000 sats : 9 outputs (14.1%)
#   531441 sats : 7 outputs (10.9%)
#   262144 sats : 6 outputs (9.4%)
#   1048576 sats : 3 outputs (4.7%)
#
# --- Suspected CoinJoin 8 ---
# Block Height: 320
# Tx Hash: 0b6387605500412b66297d23c30c039f1309ef8246bc6d9753141d460dc8d074
# Inputs: 46 | Outputs: 56
# Outputs sharing a value with another output: 91.1%
# Most common output denominations (Satoshis -> Count):
#   4782969 sats : 11 outputs (19.6%)
#   2000000 sats : 7 outputs (12.5%)
#   531441 sats : 7 outputs (12.5%)
#   50000 sats : 7 outputs (12.5%)
#   32768 sats : 7 outputs (12.5%)
#
# --- Suspected CoinJoin 9 ---
# Block Height: 331
# Tx Hash: fc40a7fe4d0f2ac469e2d60d62dccfde706249cc3049b22cf5178f5556b84039
# Inputs: 43 | Outputs: 58
# Outputs sharing a value with another output: 93.1%
# Most common output denominations (Satoshis -> Count):
#   3188646 sats : 8 outputs (13.8%)
#   5000000 sats : 7 outputs (12.1%)
#   2000000 sats : 7 outputs (12.1%)
#   65536 sats : 6 outputs (10.3%)
#   531441 sats : 5 outputs (8.6%)
#
# --- Suspected CoinJoin 10 ---
# Block Height: 344
# Tx Hash: 84a5d67dfe0fe0980e9ce67cb0d19d0a3ece8a7a1b1874c87c01f539c8f67693
# Inputs: 46 | Outputs: 57
# Outputs sharing a value with another output: 93.0%
# Most common output denominations (Satoshis -> Count):
#   2000000 sats : 9 outputs (15.8%)
#   354294 sats : 9 outputs (15.8%)
#   50000 sats : 9 outputs (15.8%)
#   4782969 sats : 5 outputs (8.8%)
#   500000 sats : 5 outputs (8.8%)
#
# --- Suspected CoinJoin 11 ---
# Block Height: 355
# Tx Hash: e08959734055bf5556bc5786d742d25a69eaa71807373c99be7c0dd609964dea
# Inputs: 40 | Outputs: 60
# Outputs sharing a value with another output: 95.0%
# Most common output denominations (Satoshis -> Count):
#   2097152 sats : 11 outputs (18.3%)
#   4782969 sats : 8 outputs (13.3%)
#   531441 sats : 7 outputs (11.7%)
#   200000 sats : 7 outputs (11.7%)
#   20000 sats : 6 outputs (10.0%)
#
# --- Suspected CoinJoin 12 ---
# Block Height: 371
# Tx Hash: 75788b1de110a7c4ee940da03c6f037a30f5525374a3f8a83f6142246b1dd377
# Inputs: 43 | Outputs: 33
# Outputs sharing a value with another output: 75.8%
# Most common output denominations (Satoshis -> Count):
#   4194304 sats : 5 outputs (15.2%)
#   354294 sats : 5 outputs (15.2%)
#   2000000 sats : 3 outputs (9.1%)
#   1048576 sats : 3 outputs (9.1%)
#   531441 sats : 3 outputs (9.1%)
#
# --- Suspected CoinJoin 13 ---
# Block Height: 385
# Tx Hash: d9d6271e949e6c426b22c6deeff13337f23881aabcc0fc5c00293260a68c9381
# Inputs: 45 | Outputs: 47
# Outputs sharing a value with another output: 91.5%
# Most common output denominations (Satoshis -> Count):
#   1000000 sats : 10 outputs (21.3%)
#   354294 sats : 5 outputs (10.6%)
#   177147 sats : 5 outputs (10.6%)
#   1594323 sats : 4 outputs (8.5%)
#   262144 sats : 4 outputs (8.5%)
#
# --- Suspected CoinJoin 14 ---
# Block Height: 398
# Tx Hash: 2773395b7756a512f86deff311a082fb6eb19717c5d474b7824703d5cb43d8d9
# Inputs: 42 | Outputs: 42
# Outputs sharing a value with another output: 88.1%
# Most common output denominations (Satoshis -> Count):
#   531441 sats : 10 outputs (23.8%)
#   4782969 sats : 7 outputs (16.7%)
#   65536 sats : 6 outputs (14.3%)
#   262144 sats : 5 outputs (11.9%)
#   32768 sats : 3 outputs (7.1%)
#
# --- Suspected CoinJoin 15 ---
# Block Height: 410
# Tx Hash: 7b5f7cff52b86f0cc4d34cfb121eba29e1cb1184cfbe7d3e1f9f1eaa6587a46b
# Inputs: 45 | Outputs: 39
# Outputs sharing a value with another output: 89.7%
# Most common output denominations (Satoshis -> Count):
#   4782969 sats : 6 outputs (15.4%)
#   1062882 sats : 5 outputs (12.8%)
#   531441 sats : 4 outputs (10.3%)
#   2097152 sats : 3 outputs (7.7%)
#   2000000 sats : 3 outputs (7.7%)
#
# --- Suspected CoinJoin 16 ---
# Block Height: 421
# Tx Hash: 324eb7861cbb1e71028be266889a57b6ae5ecef4ca36edb7f76a39d20e388e93
# Inputs: 35 | Outputs: 39
# Outputs sharing a value with another output: 84.6%
# Most common output denominations (Satoshis -> Count):
#   1062882 sats : 10 outputs (25.6%)
#   354294 sats : 7 outputs (17.9%)
#   4194304 sats : 5 outputs (12.8%)
#   531441 sats : 5 outputs (12.8%)
#   65536 sats : 2 outputs (5.1%)
#
# --- Suspected CoinJoin 17 ---
# Block Height: 435
# Tx Hash: fec3133483b67170bbf10ec709c9cc6e264f2bc30c367ce4ab6c22afa4d1bd73
# Inputs: 38 | Outputs: 47
# Outputs sharing a value with another output: 85.1%
# Most common output denominations (Satoshis -> Count):
#   531441 sats : 13 outputs (27.7%)
#   4194304 sats : 7 outputs (14.9%)
#   1048576 sats : 5 outputs (10.6%)
#   354294 sats : 3 outputs (6.4%)
#   131072 sats : 3 outputs (6.4%)
#
# --- Suspected CoinJoin 18 ---
# Block Height: 450
# Tx Hash: a93cb36e477af43d05457ff38e1f5bc660dd19be05a476ad52c8696fe3dd4d9a
# Inputs: 29 | Outputs: 37
# Outputs sharing a value with another output: 89.2%
# Most common output denominations (Satoshis -> Count):
#   2097152 sats : 10 outputs (27.0%)
#   1062882 sats : 6 outputs (16.2%)
#   500000 sats : 5 outputs (13.5%)
#   354294 sats : 4 outputs (10.8%)
#   200000 sats : 2 outputs (5.4%)
#
# --- Suspected CoinJoin 19 ---
# Block Height: 463
# Tx Hash: 29c384f5898815f3e4a456bb0a409a0e853bd32ce21e18ab549487175d82db95
# Inputs: 28 | Outputs: 32
# Outputs sharing a value with another output: 87.5%
# Most common output denominations (Satoshis -> Count):
#   354294 sats : 7 outputs (21.9%)
#   1048576 sats : 6 outputs (18.8%)
#   262144 sats : 5 outputs (15.6%)
#   3188646 sats : 4 outputs (12.5%)
#   500000 sats : 2 outputs (6.2%)
#
# --- Suspected CoinJoin 20 ---
# Block Height: 476
# Tx Hash: d226f2ca2dfa3c5cba19cd2c61fc5b808552648541c5fe03ddbdbf8bed9ad64b
# Inputs: 30 | Outputs: 29
# Outputs sharing a value with another output: 79.3%
# Most common output denominations (Satoshis -> Count):
#   3188646 sats : 7 outputs (24.1%)
#   2000000 sats : 4 outputs (13.8%)
#   531441 sats : 3 outputs (10.3%)
#   354294 sats : 3 outputs (10.3%)
#   1000000 sats : 2 outputs (6.9%)
#
# --- Suspected CoinJoin 21 ---
# Block Height: 489
# Tx Hash: 7436980fbd27be0abc0684dc30c2a5c57525513d28c8e56e6b96da56358c4ffd
# Inputs: 20 | Outputs: 29
# Outputs sharing a value with another output: 93.1%
# Most common output denominations (Satoshis -> Count):
#   3188646 sats : 6 outputs (20.7%)
#   531441 sats : 5 outputs (17.2%)
#   20000 sats : 5 outputs (17.2%)
#   65536 sats : 4 outputs (13.8%)
#   354294 sats : 3 outputs (10.3%)
#
# --- Suspected CoinJoin 22 ---
# Block Height: 504
# Tx Hash: 5b73c6e199c2e616ad619c676eac310258e3e79b32fdd3b474b03ed4ca574f97
# Inputs: 30 | Outputs: 29
# Outputs sharing a value with another output: 96.6%
# Most common output denominations (Satoshis -> Count):
#   500000 sats : 12 outputs (41.4%)
#   50000 sats : 7 outputs (24.1%)
#   262144 sats : 3 outputs (10.3%)
#   1594323 sats : 2 outputs (6.9%)
#   32768 sats : 2 outputs (6.9%)
#
# --- Suspected CoinJoin 23 ---
# Block Height: 533
# Tx Hash: b9f6b641a3c642e953166bf4a841332839bfb480eb4236a52bb2ca78ef6fc66e
# Inputs: 18 | Outputs: 23
# Outputs sharing a value with another output: 82.6%
# Most common output denominations (Satoshis -> Count):
#   1062882 sats : 6 outputs (26.1%)
#   2097152 sats : 4 outputs (17.4%)
#   354294 sats : 4 outputs (17.4%)
#   262144 sats : 3 outputs (13.0%)
#   65536 sats : 2 outputs (8.7%)
#
# --- Suspected CoinJoin 24 ---
# Block Height: 543
# Tx Hash: 8a7d127569e9180becafb899dd7c0a586572c75911ec9e2bbff8afa37895be6e
# Inputs: 16 | Outputs: 20
# Outputs sharing a value with another output: 90.0%
# Most common output denominations (Satoshis -> Count):
#   2097152 sats : 5 outputs (25.0%)
#   354294 sats : 4 outputs (20.0%)
#   118098 sats : 3 outputs (15.0%)
#   1048576 sats : 2 outputs (10.0%)
#   262144 sats : 2 outputs (10.0%)
#
# --- Suspected CoinJoin 25 ---
# Block Height: 554
# Tx Hash: 2ca52c43b2277924d747429a3f3334a20151a451151e130631166edd60db8aec
# Inputs: 19 | Outputs: 24
# Outputs sharing a value with another output: 95.8%
# Most common output denominations (Satoshis -> Count):
#   354294 sats : 6 outputs (25.0%)
#   2000000 sats : 4 outputs (16.7%)
#   1000000 sats : 3 outputs (12.5%)
#   500000 sats : 3 outputs (12.5%)
#   65536 sats : 3 outputs (12.5%)
#
# --- Suspected CoinJoin 26 ---
# Block Height: 566
# Tx Hash: 2e36b03c057fda782f46535903c0be216fc9c8ae9babf3f5cf2577ad66c636e2
# Inputs: 24 | Outputs: 24
# Outputs sharing a value with another output: 70.8%
# Most common output denominations (Satoshis -> Count):
#   354294 sats : 9 outputs (37.5%)
#   500000 sats : 5 outputs (20.8%)
#   1594323 sats : 3 outputs (12.5%)
#   262144 sats : 1 outputs (4.2%)
#   118098 sats : 1 outputs (4.2%)
#
# --- Suspected CoinJoin 27 ---
# Block Height: 583
# Tx Hash: 5f7cbebb658c83b07ca1b2b8d53da38a865501894c3acf7b4438496c56a5c3a7
# Inputs: 22 | Outputs: 28
# Outputs sharing a value with another output: 92.9%
# Most common output denominations (Satoshis -> Count):
#   354294 sats : 18 outputs (64.3%)
#   1048576 sats : 2 outputs (7.1%)
#   262144 sats : 2 outputs (7.1%)
#   65536 sats : 2 outputs (7.1%)
#   50000 sats : 2 outputs (7.1%)
#
# --- Suspected CoinJoin 28 ---
# Block Height: 594
# Tx Hash: 4ef1b67967b0c3085bbe4c499594a41cb340ad8fbf80b475474feb9432676ddb
# Inputs: 16 | Outputs: 21
# Outputs sharing a value with another output: 90.5%
# Most common output denominations (Satoshis -> Count):
#   354294 sats : 10 outputs (47.6%)
#   65536 sats : 6 outputs (28.6%)
#   1594323 sats : 3 outputs (14.3%)
#   172700 sats : 1 outputs (4.8%)
#   118098 sats : 1 outputs (4.8%)
#
# --- Suspected CoinJoin 29 ---
# Block Height: 606
# Tx Hash: 19b8a1216d76966253ad10d3d5ff85f0da28503231a3c39f07f7a7a740625b6c
# Inputs: 17 | Outputs: 17
# Outputs sharing a value with another output: 82.4%
# Most common output denominations (Satoshis -> Count):
#   1062882 sats : 7 outputs (41.2%)
#   262144 sats : 3 outputs (17.6%)
#   500000 sats : 2 outputs (11.8%)
#   16384 sats : 2 outputs (11.8%)
#   65536 sats : 1 outputs (5.9%)
#
# --- Suspected CoinJoin 30 ---
# Block Height: 621
# Tx Hash: 6064de8edf41f76e94c43b2bfc98183e460a0b29d7907ae3d047b6a71dbb1901
# Inputs: 17 | Outputs: 24
# Outputs sharing a value with another output: 87.5%
# Most common output denominations (Satoshis -> Count):
#   500000 sats : 11 outputs (45.8%)
#   354294 sats : 10 outputs (41.7%)
#   2713800 sats : 1 outputs (4.2%)
#   1468616 sats : 1 outputs (4.2%)
#   50000 sats : 1 outputs (4.2%)
#
# --- Suspected CoinJoin 31 ---
# Block Height: 632
# Tx Hash: b71cd501ad6127c73dcbf9588e9b1e5a0a91cd7c6c14b6a347b3aca9db83c977
# Inputs: 11 | Outputs: 15
# Outputs sharing a value with another output: 80.0%
# Most common output denominations (Satoshis -> Count):
#   262144 sats : 5 outputs (33.3%)
#   50000 sats : 4 outputs (26.7%)
#   65536 sats : 3 outputs (20.0%)
#   500000 sats : 1 outputs (6.7%)
#   20493 sats : 1 outputs (6.7%)
#
# --- Suspected CoinJoin 32 ---
# Block Height: 645
# Tx Hash: 27e5d270c4b8644e8a89b8cc22090d896e972672fc582ef7ad798fa38d48074a
# Inputs: 14 | Outputs: 14
# Outputs sharing a value with another output: 78.6%
# Most common output denominations (Satoshis -> Count):
#   500000 sats : 7 outputs (50.0%)
#   262144 sats : 2 outputs (14.3%)
#   65536 sats : 2 outputs (14.3%)
#   39366 sats : 1 outputs (7.1%)
#   32768 sats : 1 outputs (7.1%)
#
# --- Suspected CoinJoin 33 ---
# Block Height: 659
# Tx Hash: 04c63f2bfbe453b12c8fbf2a87f2c70332e950c7555b40d13a60cceca1158488
# Inputs: 18 | Outputs: 21
# Outputs sharing a value with another output: 71.4%
# Most common output denominations (Satoshis -> Count):
#   531441 sats : 9 outputs (42.9%)
#   354294 sats : 6 outputs (28.6%)
#   265956 sats : 1 outputs (4.8%)
#   200000 sats : 1 outputs (4.8%)
#   118098 sats : 1 outputs (4.8%)
#
# --- Suspected CoinJoin 34 ---
# Block Height: 673
# Tx Hash: 12599f5dde76e511ebf3b7cd7c759ab0f1ed2614d5cc7dc46eb25ee89cb17324
# Inputs: 14 | Outputs: 23
# Outputs sharing a value with another output: 91.3%
# Most common output denominations (Satoshis -> Count):
#   500000 sats : 8 outputs (34.8%)
#   262144 sats : 5 outputs (21.7%)
#   65536 sats : 5 outputs (21.7%)
#   32768 sats : 3 outputs (13.0%)
#   154549 sats : 1 outputs (4.3%)
#
# --- Suspected CoinJoin 35 ---
# Block Height: 686
# Tx Hash: 7ac07f06cd085d6d677f491f4b8d4066c68024bb8c4150f8a19dd4429a0e7dbc
# Inputs: 15 | Outputs: 20
# Outputs sharing a value with another output: 70.0%
# Most common output denominations (Satoshis -> Count):
#   262144 sats : 12 outputs (60.0%)
#   200000 sats : 2 outputs (10.0%)
#   206474 sats : 1 outputs (5.0%)
#   118098 sats : 1 outputs (5.0%)
#   65536 sats : 1 outputs (5.0%)
#
# --- Suspected CoinJoin 36 ---
# Block Height: 702
# Tx Hash: 0e40e18fafd0f24dec8de1ebdaa0538414e92efa21d8b0c959a62c9c982516c9
# Inputs: 19 | Outputs: 16
# Outputs sharing a value with another output: 81.2%
# Most common output denominations (Satoshis -> Count):
#   1062882 sats : 9 outputs (56.2%)
#   354294 sats : 2 outputs (12.5%)
#   50000 sats : 2 outputs (12.5%)
#   500000 sats : 1 outputs (6.2%)
#   118098 sats : 1 outputs (6.2%)
#
# --- Suspected CoinJoin 37 ---
# Block Height: 713
# Tx Hash: e6c85695a1c42c2c4edf5bbd44891bcea792a7a872d49b791834b52a9791efe2
# Inputs: 21 | Outputs: 25
# Outputs sharing a value with another output: 88.0%
# Most common output denominations (Satoshis -> Count):
#   500000 sats : 11 outputs (44.0%)
#   262144 sats : 5 outputs (20.0%)
#   118098 sats : 4 outputs (16.0%)
#   65536 sats : 2 outputs (8.0%)
#   200000 sats : 1 outputs (4.0%)
#
# --- Suspected CoinJoin 38 ---
# Block Height: 724
# Tx Hash: 305032a0877c7935145bec7554d9d980795439d0dfa3c8dc8a1c95334a98dc5e
# Inputs: 14 | Outputs: 20
# Outputs sharing a value with another output: 85.0%
# Most common output denominations (Satoshis -> Count):
#   354294 sats : 9 outputs (45.0%)
#   65536 sats : 6 outputs (30.0%)
#   118098 sats : 2 outputs (10.0%)
#   200000 sats : 1 outputs (5.0%)
#   50000 sats : 1 outputs (5.0%)
#
# --- Suspected CoinJoin 39 ---
# Block Height: 738
# Tx Hash: bd567a42543e74d128e0e441b82446754b349da7efc232c4c73b221b753d1abe
# Inputs: 19 | Outputs: 20
# Outputs sharing a value with another output: 80.0%
# Most common output denominations (Satoshis -> Count):
#   354294 sats : 12 outputs (60.0%)
#   65536 sats : 2 outputs (10.0%)
#   50000 sats : 2 outputs (10.0%)
#   200000 sats : 1 outputs (5.0%)
#   118098 sats : 1 outputs (5.0%)
#
# --- Suspected CoinJoin 40 ---
# Block Height: 750
# Tx Hash: 060638a273aeaa102f137a6a8a12f67d39feeddebb4c045007a65d17b0a52c24
# Inputs: 15 | Outputs: 18
# Outputs sharing a value with another output: 83.3%
# Most common output denominations (Satoshis -> Count):
#   354294 sats : 11 outputs (61.1%)
#   200000 sats : 2 outputs (11.1%)
#   39366 sats : 2 outputs (11.1%)
#   291560 sats : 1 outputs (5.6%)
#   65536 sats : 1 outputs (5.6%)
#
# --- Suspected CoinJoin 41 ---
# Block Height: 762
# Tx Hash: 90064d59a5c017941b15014982f592723a3ab47c44308e0e213c6cf42fb92127
# Inputs: 15 | Outputs: 16
# Outputs sharing a value with another output: 87.5%
# Most common output denominations (Satoshis -> Count):
#   1048576 sats : 6 outputs (37.5%)
#   65536 sats : 3 outputs (18.8%)
#   39366 sats : 3 outputs (18.8%)
#   50000 sats : 2 outputs (12.5%)
#   262144 sats : 1 outputs (6.2%)
#
# --- Suspected CoinJoin 42 ---
# Block Height: 772
# Tx Hash: 312134095c032824dfe4993cda9a34aaa61ab5ca24a2ed5ffaf346a08f601a95
# Inputs: 13 | Outputs: 12
# Outputs sharing a value with another output: 66.7%
# Most common output denominations (Satoshis -> Count):
#   354294 sats : 8 outputs (66.7%)
#   262144 sats : 1 outputs (8.3%)
#   32768 sats : 1 outputs (8.3%)
#   17556 sats : 1 outputs (8.3%)
#   8202 sats : 1 outputs (8.3%)
#
# --- Suspected CoinJoin 43 ---
# Block Height: 797
# Tx Hash: 0002959b83ecfa2ba20bbf3387fa6fc756b69ac87a559978c5751777fe477db6
# Inputs: 17 | Outputs: 15
# Outputs sharing a value with another output: 80.0%
# Most common output denominations (Satoshis -> Count):
#   354294 sats : 5 outputs (33.3%)
#   1048576 sats : 3 outputs (20.0%)
#   118098 sats : 2 outputs (13.3%)
#   20000 sats : 2 outputs (13.3%)
#   1000000 sats : 1 outputs (6.7%)
#
# --- Suspected CoinJoin 44 ---
# Block Height: 811
# Tx Hash: 1fdae3d0e8b9b4acd283df20eee465054833e7b2cebd40c2dd09c700341becbe
# Inputs: 18 | Outputs: 16
# Outputs sharing a value with another output: 81.2%
# Most common output denominations (Satoshis -> Count):
#   1000000 sats : 7 outputs (43.8%)
#   354294 sats : 2 outputs (12.5%)
#   39366 sats : 2 outputs (12.5%)
#   20000 sats : 2 outputs (12.5%)
#   262144 sats : 1 outputs (6.2%)
# Testing with overridden min_input_count...
# Success! Detected 16 txs using string 'wasabi2' with min_inputs=10
#
# --- Suspected CoinJoin 1 (bafdc4a656d7506801ad688eac63c07518481967ba160a205087156bf47f9bbd) ---
# Input Types:
#   witness_pubkeyhash: 15
# Output Types:
#   witness_pubkeyhash: 25
#   witness_unknown: 31
#
# --- Suspected CoinJoin 2 (8061a947455a7c0ea54dcc7e4af1c4062f1b26ac3a0a0c3c1a2f1b52c68794a4) ---
# Input Types:
#   witness_pubkeyhash: 25
#   witness_unknown: 8
# Output Types:
#   witness_pubkeyhash: 25
#   witness_unknown: 42
#
# --- Suspected CoinJoin 3 (1c21ea259bafabccbf7e3b047935237da7d035f17e1290b4da1910cc4e79e8a8) ---
# Input Types:
#   witness_pubkeyhash: 26
#   witness_unknown: 21
# Output Types:
#   witness_pubkeyhash: 15
#   witness_unknown: 51
#
# --- Suspected CoinJoin 4 (eb738a391cfcce73da85c1857a9717ae3b8d12dfd5d43550ae592876622c5de5) ---
# Input Types:
#   witness_pubkeyhash: 15
#   witness_unknown: 32
# Output Types:
#   witness_unknown: 36
#   witness_pubkeyhash: 20
#
# --- Suspected CoinJoin 5 (5897a02d02cbf55fc3f92b40f9026f4c9425e28b08d4424edcdb60003956837b) ---
# Input Types:
#   witness_unknown: 39
#   witness_pubkeyhash: 20
# Output Types:
#   witness_unknown: 53
#   witness_pubkeyhash: 19
#
# --- Suspected CoinJoin 6 (49ace62f4ad8c584e88e6a0908c039ddc548c70b0e1242f7c1f9cd14924b9141) ---
# Input Types:
#   witness_unknown: 32
#   witness_pubkeyhash: 27
# Output Types:
#   witness_pubkeyhash: 22
#   witness_unknown: 41
#
# --- Suspected CoinJoin 7 (50f0a89799a4bc5e18b124500e887e630fd10284778dbd27e77ebc3960daba7d) ---
# Input Types:
#   witness_pubkeyhash: 19
#   witness_unknown: 39
# Output Types:
#   witness_pubkeyhash: 26
#   witness_unknown: 38
#
# --- Suspected CoinJoin 8 (0b6387605500412b66297d23c30c039f1309ef8246bc6d9753141d460dc8d074) ---
# Input Types:
#   witness_unknown: 31
#   witness_pubkeyhash: 15
# Output Types:
#   witness_unknown: 30
#   witness_pubkeyhash: 26
#
# --- Suspected CoinJoin 9 (fc40a7fe4d0f2ac469e2d60d62dccfde706249cc3049b22cf5178f5556b84039) ---
# Input Types:
#   witness_pubkeyhash: 18
#   witness_unknown: 25
# Output Types:
#   witness_pubkeyhash: 21
#   witness_unknown: 37
#
# --- Suspected CoinJoin 10 (84a5d67dfe0fe0980e9ce67cb0d19d0a3ece8a7a1b1874c87c01f539c8f67693) ---
# Input Types:
#   witness_pubkeyhash: 16
#   witness_unknown: 30
# Output Types:
#   witness_pubkeyhash: 23
#   witness_unknown: 34
#
# --- Suspected CoinJoin 11 (e08959734055bf5556bc5786d742d25a69eaa71807373c99be7c0dd609964dea) ---
# Input Types:
#   witness_pubkeyhash: 20
#   witness_unknown: 20
# Output Types:
#   witness_unknown: 36
#   witness_pubkeyhash: 24
#
# --- Suspected CoinJoin 12 (75788b1de110a7c4ee940da03c6f037a30f5525374a3f8a83f6142246b1dd377) ---
# Input Types:
#   witness_unknown: 25
#   witness_pubkeyhash: 18
# Output Types:
#   witness_pubkeyhash: 17
#   witness_unknown: 16
#
# --- Suspected CoinJoin 13 (d9d6271e949e6c426b22c6deeff13337f23881aabcc0fc5c00293260a68c9381) ---
# Input Types:
#   witness_pubkeyhash: 23
#   witness_unknown: 22
# Output Types:
#   witness_pubkeyhash: 22
#   witness_unknown: 25
#
# --- Suspected CoinJoin 14 (2773395b7756a512f86deff311a082fb6eb19717c5d474b7824703d5cb43d8d9) ---
# Input Types:
#   witness_pubkeyhash: 21
#   witness_unknown: 21
# Output Types:
#   witness_pubkeyhash: 7
#   witness_unknown: 35
#
# --- Suspected CoinJoin 15 (7b5f7cff52b86f0cc4d34cfb121eba29e1cb1184cfbe7d3e1f9f1eaa6587a46b) ---
# Input Types:
#   witness_pubkeyhash: 18
#   witness_unknown: 27
# Output Types:
#   witness_pubkeyhash: 11
#   witness_unknown: 28
#
# --- Suspected CoinJoin 16 (324eb7861cbb1e71028be266889a57b6ae5ecef4ca36edb7f76a39d20e388e93) ---
# Input Types:
#   witness_pubkeyhash: 12
#   witness_unknown: 23
# Output Types:
#   witness_pubkeyhash: 18
#   witness_unknown: 21
#
# --- Suspected CoinJoin 17 (fec3133483b67170bbf10ec709c9cc6e264f2bc30c367ce4ab6c22afa4d1bd73) ---
# Input Types:
#   witness_unknown: 21
#   witness_pubkeyhash: 17
# Output Types:
#   witness_pubkeyhash: 16
#   witness_unknown: 31
#
# --- Suspected CoinJoin 18 (a93cb36e477af43d05457ff38e1f5bc660dd19be05a476ad52c8696fe3dd4d9a) ---
# Input Types:
#   witness_unknown: 20
#   witness_pubkeyhash: 9
# Output Types:
#   witness_pubkeyhash: 20
#   witness_unknown: 17
#
# --- Suspected CoinJoin 19 (29c384f5898815f3e4a456bb0a409a0e853bd32ce21e18ab549487175d82db95) ---
# Input Types:
#   witness_pubkeyhash: 12
#   witness_unknown: 16
# Output Types:
#   witness_pubkeyhash: 22
#   witness_unknown: 10
#
# --- Suspected CoinJoin 20 (d226f2ca2dfa3c5cba19cd2c61fc5b808552648541c5fe03ddbdbf8bed9ad64b) ---
# Input Types:
#   witness_pubkeyhash: 13
#   witness_unknown: 17
# Output Types:
#   witness_pubkeyhash: 6
#   witness_unknown: 23
#
# --- Suspected CoinJoin 21 (7436980fbd27be0abc0684dc30c2a5c57525513d28c8e56e6b96da56358c4ffd) ---
# Input Types:
#   witness_unknown: 9
#   witness_pubkeyhash: 11
# Output Types:
#   witness_pubkeyhash: 11
#   witness_unknown: 18
#
# --- Suspected CoinJoin 22 (5b73c6e199c2e616ad619c676eac310258e3e79b32fdd3b474b03ed4ca574f97) ---
# Input Types:
#   witness_pubkeyhash: 13
#   witness_unknown: 17
# Output Types:
#   witness_unknown: 6
#   witness_pubkeyhash: 23
#
# --- Suspected CoinJoin 23 (b9f6b641a3c642e953166bf4a841332839bfb480eb4236a52bb2ca78ef6fc66e) ---
# Input Types:
#   witness_unknown: 9
#   witness_pubkeyhash: 9
# Output Types:
#   witness_pubkeyhash: 10
#   witness_unknown: 13
#
# --- Suspected CoinJoin 24 (8a7d127569e9180becafb899dd7c0a586572c75911ec9e2bbff8afa37895be6e) ---
# Input Types:
#   witness_unknown: 7
#   witness_pubkeyhash: 9
# Output Types:
#   witness_pubkeyhash: 15
#   witness_unknown: 5
#
# --- Suspected CoinJoin 25 (2ca52c43b2277924d747429a3f3334a20151a451151e130631166edd60db8aec) ---
# Input Types:
#   witness_unknown: 11
#   witness_pubkeyhash: 8
# Output Types:
#   witness_pubkeyhash: 14
#   witness_unknown: 10
#
# --- Suspected CoinJoin 26 (2e36b03c057fda782f46535903c0be216fc9c8ae9babf3f5cf2577ad66c636e2) ---
# Input Types:
#   witness_pubkeyhash: 12
#   witness_unknown: 12
# Output Types:
#   witness_unknown: 14
#   witness_pubkeyhash: 10
#
# --- Suspected CoinJoin 27 (5f7cbebb658c83b07ca1b2b8d53da38a865501894c3acf7b4438496c56a5c3a7) ---
# Input Types:
#   witness_pubkeyhash: 12
#   witness_unknown: 10
# Output Types:
#   witness_pubkeyhash: 6
#   witness_unknown: 22
#
# --- Suspected CoinJoin 28 (4ef1b67967b0c3085bbe4c499594a41cb340ad8fbf80b475474feb9432676ddb) ---
# Input Types:
#   witness_pubkeyhash: 9
#   witness_unknown: 7
# Output Types:
#   witness_unknown: 17
#   witness_pubkeyhash: 4
#
# --- Suspected CoinJoin 29 (19b8a1216d76966253ad10d3d5ff85f0da28503231a3c39f07f7a7a740625b6c) ---
# Input Types:
#   witness_pubkeyhash: 9
#   witness_unknown: 8
# Output Types:
#   witness_pubkeyhash: 10
#   witness_unknown: 7
#
# --- Suspected CoinJoin 30 (6064de8edf41f76e94c43b2bfc98183e460a0b29d7907ae3d047b6a71dbb1901) ---
# Input Types:
#   witness_pubkeyhash: 6
#   witness_unknown: 11
# Output Types:
#   witness_pubkeyhash: 5
#   witness_unknown: 19
#
# --- Suspected CoinJoin 31 (b71cd501ad6127c73dcbf9588e9b1e5a0a91cd7c6c14b6a347b3aca9db83c977) ---
# Input Types:
#   witness_unknown: 10
#   witness_pubkeyhash: 1
# Output Types:
#   witness_pubkeyhash: 10
#   witness_unknown: 5
#
# --- Suspected CoinJoin 32 (27e5d270c4b8644e8a89b8cc22090d896e972672fc582ef7ad798fa38d48074a) ---
# Input Types:
#   witness_pubkeyhash: 5
#   witness_unknown: 9
# Output Types:
#   witness_pubkeyhash: 4
#   witness_unknown: 10
#
# --- Suspected CoinJoin 33 (04c63f2bfbe453b12c8fbf2a87f2c70332e950c7555b40d13a60cceca1158488) ---
# Input Types:
#   witness_unknown: 12
#   witness_pubkeyhash: 6
# Output Types:
#   witness_pubkeyhash: 5
#   witness_unknown: 16
#
# --- Suspected CoinJoin 34 (12599f5dde76e511ebf3b7cd7c759ab0f1ed2614d5cc7dc46eb25ee89cb17324) ---
# Input Types:
#   witness_pubkeyhash: 4
#   witness_unknown: 10
# Output Types:
#   witness_pubkeyhash: 14
#   witness_unknown: 9
#
# --- Suspected CoinJoin 35 (7ac07f06cd085d6d677f491f4b8d4066c68024bb8c4150f8a19dd4429a0e7dbc) ---
# Input Types:
#   witness_unknown: 10
#   witness_pubkeyhash: 5
# Output Types:
#   witness_unknown: 15
#   witness_pubkeyhash: 5
#
# --- Suspected CoinJoin 36 (0e40e18fafd0f24dec8de1ebdaa0538414e92efa21d8b0c959a62c9c982516c9) ---
# Input Types:
#   witness_unknown: 14
#   witness_pubkeyhash: 5
# Output Types:
#   witness_pubkeyhash: 5
#   witness_unknown: 11
#
# --- Suspected CoinJoin 37 (e6c85695a1c42c2c4edf5bbd44891bcea792a7a872d49b791834b52a9791efe2) ---
# Input Types:
#   witness_pubkeyhash: 9
#   witness_unknown: 12
# Output Types:
#   witness_pubkeyhash: 14
#   witness_unknown: 11
#
# --- Suspected CoinJoin 38 (305032a0877c7935145bec7554d9d980795439d0dfa3c8dc8a1c95334a98dc5e) ---
# Input Types:
#   witness_unknown: 12
#   witness_pubkeyhash: 2
# Output Types:
#   witness_pubkeyhash: 8
#   witness_unknown: 12
#
# --- Suspected CoinJoin 39 (bd567a42543e74d128e0e441b82446754b349da7efc232c4c73b221b753d1abe) ---
# Input Types:
#   witness_unknown: 12
#   witness_pubkeyhash: 7
# Output Types:
#   witness_unknown: 15
#   witness_pubkeyhash: 5
#
# --- Suspected CoinJoin 40 (060638a273aeaa102f137a6a8a12f67d39feeddebb4c045007a65d17b0a52c24) ---
# Input Types:
#   witness_pubkeyhash: 7
#   witness_unknown: 8
# Output Types:
#   witness_unknown: 14
#   witness_pubkeyhash: 4
#
# --- Suspected CoinJoin 41 (90064d59a5c017941b15014982f592723a3ab47c44308e0e213c6cf42fb92127) ---
# Input Types:
#   witness_pubkeyhash: 7
#   witness_unknown: 8
# Output Types:
#   witness_pubkeyhash: 14
#   witness_unknown: 2
#
# --- Suspected CoinJoin 42 (312134095c032824dfe4993cda9a34aaa61ab5ca24a2ed5ffaf346a08f601a95) ---
# Input Types:
#   witness_pubkeyhash: 7
#   witness_unknown: 6
# Output Types:
#   witness_pubkeyhash: 9
#   witness_unknown: 3
#
# --- Suspected CoinJoin 43 (0002959b83ecfa2ba20bbf3387fa6fc756b69ac87a559978c5751777fe477db6) ---
# Input Types:
#   witness_unknown: 6
#   witness_pubkeyhash: 11
# Output Types:
#   witness_pubkeyhash: 11
#   witness_unknown: 4
#
# --- Suspected CoinJoin 44 (1fdae3d0e8b9b4acd283df20eee465054833e7b2cebd40c2dd09c700341becbe) ---
# Input Types:
#   witness_pubkeyhash: 8
#   witness_unknown: 10
# Output Types:
#   witness_unknown: 9
#   witness_pubkeyhash: 7
#
# --- Suspected CoinJoin 1 ---
# Sorted strictly descending? True
# --- Suspected CoinJoin 1 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 2 ---
# Total Outputs: 67
# Unique Addresses: 67
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 3 ---
# Total Outputs: 66
# Unique Addresses: 66
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 4 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 5 ---
# Total Outputs: 72
# Unique Addresses: 72
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 6 ---
# Total Outputs: 63
# Unique Addresses: 63
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 7 ---
# Total Outputs: 64
# Unique Addresses: 64
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 8 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 9 ---
# Total Outputs: 58
# Unique Addresses: 58
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 10 ---
# Total Outputs: 57
# Unique Addresses: 57
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 11 ---
# Total Outputs: 60
# Unique Addresses: 60
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 12 ---
# Total Outputs: 33
# Unique Addresses: 33
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 13 ---
# Total Outputs: 47
# Unique Addresses: 47
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 14 ---
# Total Outputs: 42
# Unique Addresses: 42
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 15 ---
# Total Outputs: 39
# Unique Addresses: 39
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 16 ---
# Total Outputs: 39
# Unique Addresses: 39
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 17 ---
# Total Outputs: 47
# Unique Addresses: 47
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 18 ---
# Total Outputs: 37
# Unique Addresses: 37
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 19 ---
# Total Outputs: 32
# Unique Addresses: 32
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 20 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 21 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 22 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 23 ---
# Total Outputs: 23
# Unique Addresses: 23
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 24 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 25 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 26 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 27 ---
# Total Outputs: 28
# Unique Addresses: 28
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 28 ---
# Total Outputs: 21
# Unique Addresses: 21
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 29 ---
# Total Outputs: 17
# Unique Addresses: 17
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 30 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 31 ---
# Total Outputs: 15
# Unique Addresses: 15
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 32 ---
# Total Outputs: 14
# Unique Addresses: 14
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 33 ---
# Total Outputs: 21
# Unique Addresses: 21
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 34 ---
# Total Outputs: 23
# Unique Addresses: 23
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 35 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 36 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 37 ---
# Total Outputs: 25
# Unique Addresses: 25
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 38 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 39 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 40 ---
# Total Outputs: 18
# Unique Addresses: 18
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 41 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 42 ---
# Total Outputs: 12
# Unique Addresses: 12
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 43 ---
# Total Outputs: 15
# Unique Addresses: 15
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 44 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
#
# --- Suspected CoinJoin 2 ---
# Sorted strictly descending? True
# --- Suspected CoinJoin 1 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 2 ---
# Total Outputs: 67
# Unique Addresses: 67
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 3 ---
# Total Outputs: 66
# Unique Addresses: 66
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 4 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 5 ---
# Total Outputs: 72
# Unique Addresses: 72
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 6 ---
# Total Outputs: 63
# Unique Addresses: 63
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 7 ---
# Total Outputs: 64
# Unique Addresses: 64
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 8 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 9 ---
# Total Outputs: 58
# Unique Addresses: 58
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 10 ---
# Total Outputs: 57
# Unique Addresses: 57
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 11 ---
# Total Outputs: 60
# Unique Addresses: 60
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 12 ---
# Total Outputs: 33
# Unique Addresses: 33
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 13 ---
# Total Outputs: 47
# Unique Addresses: 47
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 14 ---
# Total Outputs: 42
# Unique Addresses: 42
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 15 ---
# Total Outputs: 39
# Unique Addresses: 39
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 16 ---
# Total Outputs: 39
# Unique Addresses: 39
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 17 ---
# Total Outputs: 47
# Unique Addresses: 47
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 18 ---
# Total Outputs: 37
# Unique Addresses: 37
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 19 ---
# Total Outputs: 32
# Unique Addresses: 32
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 20 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 21 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 22 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 23 ---
# Total Outputs: 23
# Unique Addresses: 23
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 24 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 25 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 26 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 27 ---
# Total Outputs: 28
# Unique Addresses: 28
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 28 ---
# Total Outputs: 21
# Unique Addresses: 21
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 29 ---
# Total Outputs: 17
# Unique Addresses: 17
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 30 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 31 ---
# Total Outputs: 15
# Unique Addresses: 15
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 32 ---
# Total Outputs: 14
# Unique Addresses: 14
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 33 ---
# Total Outputs: 21
# Unique Addresses: 21
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 34 ---
# Total Outputs: 23
# Unique Addresses: 23
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 35 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 36 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 37 ---
# Total Outputs: 25
# Unique Addresses: 25
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 38 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 39 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 40 ---
# Total Outputs: 18
# Unique Addresses: 18
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 41 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 42 ---
# Total Outputs: 12
# Unique Addresses: 12
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 43 ---
# Total Outputs: 15
# Unique Addresses: 15
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 44 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
#
# --- Suspected CoinJoin 3 ---
# Sorted strictly descending? True
# --- Suspected CoinJoin 1 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 2 ---
# Total Outputs: 67
# Unique Addresses: 67
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 3 ---
# Total Outputs: 66
# Unique Addresses: 66
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 4 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 5 ---
# Total Outputs: 72
# Unique Addresses: 72
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 6 ---
# Total Outputs: 63
# Unique Addresses: 63
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 7 ---
# Total Outputs: 64
# Unique Addresses: 64
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 8 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 9 ---
# Total Outputs: 58
# Unique Addresses: 58
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 10 ---
# Total Outputs: 57
# Unique Addresses: 57
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 11 ---
# Total Outputs: 60
# Unique Addresses: 60
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 12 ---
# Total Outputs: 33
# Unique Addresses: 33
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 13 ---
# Total Outputs: 47
# Unique Addresses: 47
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 14 ---
# Total Outputs: 42
# Unique Addresses: 42
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 15 ---
# Total Outputs: 39
# Unique Addresses: 39
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 16 ---
# Total Outputs: 39
# Unique Addresses: 39
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 17 ---
# Total Outputs: 47
# Unique Addresses: 47
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 18 ---
# Total Outputs: 37
# Unique Addresses: 37
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 19 ---
# Total Outputs: 32
# Unique Addresses: 32
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 20 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 21 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 22 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 23 ---
# Total Outputs: 23
# Unique Addresses: 23
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 24 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 25 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 26 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 27 ---
# Total Outputs: 28
# Unique Addresses: 28
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 28 ---
# Total Outputs: 21
# Unique Addresses: 21
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 29 ---
# Total Outputs: 17
# Unique Addresses: 17
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 30 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 31 ---
# Total Outputs: 15
# Unique Addresses: 15
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 32 ---
# Total Outputs: 14
# Unique Addresses: 14
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 33 ---
# Total Outputs: 21
# Unique Addresses: 21
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 34 ---
# Total Outputs: 23
# Unique Addresses: 23
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 35 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 36 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 37 ---
# Total Outputs: 25
# Unique Addresses: 25
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 38 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 39 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 40 ---
# Total Outputs: 18
# Unique Addresses: 18
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 41 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 42 ---
# Total Outputs: 12
# Unique Addresses: 12
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 43 ---
# Total Outputs: 15
# Unique Addresses: 15
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 44 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
#
# --- Suspected CoinJoin 4 ---
# Sorted strictly descending? True
# --- Suspected CoinJoin 1 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 2 ---
# Total Outputs: 67
# Unique Addresses: 67
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 3 ---
# Total Outputs: 66
# Unique Addresses: 66
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 4 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 5 ---
# Total Outputs: 72
# Unique Addresses: 72
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 6 ---
# Total Outputs: 63
# Unique Addresses: 63
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 7 ---
# Total Outputs: 64
# Unique Addresses: 64
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 8 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 9 ---
# Total Outputs: 58
# Unique Addresses: 58
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 10 ---
# Total Outputs: 57
# Unique Addresses: 57
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 11 ---
# Total Outputs: 60
# Unique Addresses: 60
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 12 ---
# Total Outputs: 33
# Unique Addresses: 33
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 13 ---
# Total Outputs: 47
# Unique Addresses: 47
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 14 ---
# Total Outputs: 42
# Unique Addresses: 42
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 15 ---
# Total Outputs: 39
# Unique Addresses: 39
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 16 ---
# Total Outputs: 39
# Unique Addresses: 39
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 17 ---
# Total Outputs: 47
# Unique Addresses: 47
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 18 ---
# Total Outputs: 37
# Unique Addresses: 37
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 19 ---
# Total Outputs: 32
# Unique Addresses: 32
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 20 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 21 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 22 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 23 ---
# Total Outputs: 23
# Unique Addresses: 23
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 24 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 25 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 26 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 27 ---
# Total Outputs: 28
# Unique Addresses: 28
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 28 ---
# Total Outputs: 21
# Unique Addresses: 21
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 29 ---
# Total Outputs: 17
# Unique Addresses: 17
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 30 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 31 ---
# Total Outputs: 15
# Unique Addresses: 15
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 32 ---
# Total Outputs: 14
# Unique Addresses: 14
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 33 ---
# Total Outputs: 21
# Unique Addresses: 21
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 34 ---
# Total Outputs: 23
# Unique Addresses: 23
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 35 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 36 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 37 ---
# Total Outputs: 25
# Unique Addresses: 25
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 38 ---
# Total Outputs: 20
# ...
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 31 ---
# Total Outputs: 15
# Unique Addresses: 15
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 32 ---
# Total Outputs: 14
# Unique Addresses: 14
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 33 ---
# Total Outputs: 21
# Unique Addresses: 21
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 34 ---
# Total Outputs: 23
# Unique Addresses: 23
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 35 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 36 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 37 ---
# Total Outputs: 25
# Unique Addresses: 25
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 38 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 39 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 40 ---
# Total Outputs: 18
# Unique Addresses: 18
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 41 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 42 ---
# Total Outputs: 12
# Unique Addresses: 12
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 43 ---
# Total Outputs: 15
# Unique Addresses: 15
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 44 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
#
# --- Suspected CoinJoin 42 ---
# Sorted strictly descending? True
# --- Suspected CoinJoin 1 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 2 ---
# Total Outputs: 67
# Unique Addresses: 67
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 3 ---
# Total Outputs: 66
# Unique Addresses: 66
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 4 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 5 ---
# Total Outputs: 72
# Unique Addresses: 72
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 6 ---
# Total Outputs: 63
# Unique Addresses: 63
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 7 ---
# Total Outputs: 64
# Unique Addresses: 64
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 8 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 9 ---
# Total Outputs: 58
# Unique Addresses: 58
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 10 ---
# Total Outputs: 57
# Unique Addresses: 57
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 11 ---
# Total Outputs: 60
# Unique Addresses: 60
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 12 ---
# Total Outputs: 33
# Unique Addresses: 33
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 13 ---
# Total Outputs: 47
# Unique Addresses: 47
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 14 ---
# Total Outputs: 42
# Unique Addresses: 42
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 15 ---
# Total Outputs: 39
# Unique Addresses: 39
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 16 ---
# Total Outputs: 39
# Unique Addresses: 39
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 17 ---
# Total Outputs: 47
# Unique Addresses: 47
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 18 ---
# Total Outputs: 37
# Unique Addresses: 37
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 19 ---
# Total Outputs: 32
# Unique Addresses: 32
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 20 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 21 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 22 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 23 ---
# Total Outputs: 23
# Unique Addresses: 23
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 24 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 25 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 26 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 27 ---
# Total Outputs: 28
# Unique Addresses: 28
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 28 ---
# Total Outputs: 21
# Unique Addresses: 21
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 29 ---
# Total Outputs: 17
# Unique Addresses: 17
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 30 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 31 ---
# Total Outputs: 15
# Unique Addresses: 15
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 32 ---
# Total Outputs: 14
# Unique Addresses: 14
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 33 ---
# Total Outputs: 21
# Unique Addresses: 21
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 34 ---
# Total Outputs: 23
# Unique Addresses: 23
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 35 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 36 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 37 ---
# Total Outputs: 25
# Unique Addresses: 25
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 38 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 39 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 40 ---
# Total Outputs: 18
# Unique Addresses: 18
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 41 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 42 ---
# Total Outputs: 12
# Unique Addresses: 12
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 43 ---
# Total Outputs: 15
# Unique Addresses: 15
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 44 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
#
# --- Suspected CoinJoin 43 ---
# Sorted strictly descending? True
# --- Suspected CoinJoin 1 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 2 ---
# Total Outputs: 67
# Unique Addresses: 67
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 3 ---
# Total Outputs: 66
# Unique Addresses: 66
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 4 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 5 ---
# Total Outputs: 72
# Unique Addresses: 72
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 6 ---
# Total Outputs: 63
# Unique Addresses: 63
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 7 ---
# Total Outputs: 64
# Unique Addresses: 64
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 8 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 9 ---
# Total Outputs: 58
# Unique Addresses: 58
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 10 ---
# Total Outputs: 57
# Unique Addresses: 57
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 11 ---
# Total Outputs: 60
# Unique Addresses: 60
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 12 ---
# Total Outputs: 33
# Unique Addresses: 33
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 13 ---
# Total Outputs: 47
# Unique Addresses: 47
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 14 ---
# Total Outputs: 42
# Unique Addresses: 42
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 15 ---
# Total Outputs: 39
# Unique Addresses: 39
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 16 ---
# Total Outputs: 39
# Unique Addresses: 39
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 17 ---
# Total Outputs: 47
# Unique Addresses: 47
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 18 ---
# Total Outputs: 37
# Unique Addresses: 37
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 19 ---
# Total Outputs: 32
# Unique Addresses: 32
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 20 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 21 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 22 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 23 ---
# Total Outputs: 23
# Unique Addresses: 23
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 24 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 25 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 26 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 27 ---
# Total Outputs: 28
# Unique Addresses: 28
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 28 ---
# Total Outputs: 21
# Unique Addresses: 21
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 29 ---
# Total Outputs: 17
# Unique Addresses: 17
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 30 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 31 ---
# Total Outputs: 15
# Unique Addresses: 15
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 32 ---
# Total Outputs: 14
# Unique Addresses: 14
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 33 ---
# Total Outputs: 21
# Unique Addresses: 21
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 34 ---
# Total Outputs: 23
# Unique Addresses: 23
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 35 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 36 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 37 ---
# Total Outputs: 25
# Unique Addresses: 25
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 38 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 39 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 40 ---
# Total Outputs: 18
# Unique Addresses: 18
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 41 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 42 ---
# Total Outputs: 12
# Unique Addresses: 12
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 43 ---
# Total Outputs: 15
# Unique Addresses: 15
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 44 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
#
# --- Suspected CoinJoin 44 ---
# Sorted strictly descending? True
# --- Suspected CoinJoin 1 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 2 ---
# Total Outputs: 67
# Unique Addresses: 67
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 3 ---
# Total Outputs: 66
# Unique Addresses: 66
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 4 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 5 ---
# Total Outputs: 72
# Unique Addresses: 72
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 6 ---
# Total Outputs: 63
# Unique Addresses: 63
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 7 ---
# Total Outputs: 64
# Unique Addresses: 64
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 8 ---
# Total Outputs: 56
# Unique Addresses: 56
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 9 ---
# Total Outputs: 58
# Unique Addresses: 58
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 10 ---
# Total Outputs: 57
# Unique Addresses: 57
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 11 ---
# Total Outputs: 60
# Unique Addresses: 60
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 12 ---
# Total Outputs: 33
# Unique Addresses: 33
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 13 ---
# Total Outputs: 47
# Unique Addresses: 47
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 14 ---
# Total Outputs: 42
# Unique Addresses: 42
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 15 ---
# Total Outputs: 39
# Unique Addresses: 39
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 16 ---
# Total Outputs: 39
# Unique Addresses: 39
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 17 ---
# Total Outputs: 47
# Unique Addresses: 47
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 18 ---
# Total Outputs: 37
# Unique Addresses: 37
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 19 ---
# Total Outputs: 32
# Unique Addresses: 32
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 20 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 21 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 22 ---
# Total Outputs: 29
# Unique Addresses: 29
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 23 ---
# Total Outputs: 23
# Unique Addresses: 23
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 24 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 25 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 26 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 27 ---
# Total Outputs: 28
# Unique Addresses: 28
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 28 ---
# Total Outputs: 21
# Unique Addresses: 21
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 29 ---
# Total Outputs: 17
# Unique Addresses: 17
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 30 ---
# Total Outputs: 24
# Unique Addresses: 24
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 31 ---
# Total Outputs: 15
# Unique Addresses: 15
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 32 ---
# Total Outputs: 14
# Unique Addresses: 14
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 33 ---
# Total Outputs: 21
# Unique Addresses: 21
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 34 ---
# Total Outputs: 23
# Unique Addresses: 23
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 35 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 36 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 37 ---
# Total Outputs: 25
# Unique Addresses: 25
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 38 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 39 ---
# Total Outputs: 20
# Unique Addresses: 20
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 40 ---
# Total Outputs: 18
# Unique Addresses: 18
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 41 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 42 ---
# Total Outputs: 12
# Unique Addresses: 12
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 43 ---
# Total Outputs: 15
# Unique Addresses: 15
# ✅ Passed the C++ unique address check.
# --- Suspected CoinJoin 44 ---
# Total Outputs: 16
# Unique Addresses: 16
# ✅ Passed the C++ unique address check.

# %% [markdown]
# # Percentage of used scripts in time
#
# Observe how the used scripts changed over time. All scripts using witnesses are in the `SegWit` category.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %time data = chain.get_count_of_address_types_for_each_day(0, len(chain))

print(data)

df = pd.DataFrame.from_dict(data, orient='index')
df = df.fillna(0).T  # Transpose to make days the rows
df.index = pd.to_datetime(df.index.map(lambda x: datetime.utcfromtimestamp(x * 86400)))

group_mapping = {
    #blocksci.address_type.witness_pubkeyhash: "segwit",
    #blocksci.address_type.witness_unknown: "segwit",
    #blocksci.address_type.nonstandard: "", 
    #blocksci.address_type.witness_scripthash: "segwit",
}

# segwit_total = df[group_mapping.keys()].sum(axis=1)  # Sum up all segwit categories
# df["SegWit"] = segwit_total 

df = df.drop(columns=group_mapping.keys())

df = df.resample('M').sum()

# df['total'] = df.sum(axis=1)

# percentages = df.div(df['total'], axis=0) * 100
# percentages = percentages.drop(columns=['total'])


plt.figure(figsize=(16, 8))
df.plot(kind='line', ax=plt.gca())

plt.legend(title='Address Group', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.title('Bitcoin Address Group Usage Over Time')
plt.xlabel('Date')
plt.ylabel('Percentage')
plt.yscale('log')
plt.grid()

plt.tight_layout()

# plt.savefig('/mnt/blocksci/address_group_usage_percent.png')
plt.show()

print(df.sum())
# Out:
# CPU times: user 10.8 ms, sys: 9.2 ms, total: 20 ms
# Wall time: 8.55 ms
# {address_type.nulldata: {20559: 40, 20558: 799}, address_type.witness_pubkeyhash: {20559: 47, 20558: 1768}, address_type.pubkey: {15007: 1}, address_type.witness_unknown: {20559: 9, 20558: 896}}
# Null data                      839.0
# Pay to witness pubkey hash    1815.0
# Pay to witness unknown         905.0
# Pay to pubkey                    1.0
# dtype: float64

# %% [markdown]
# # CoinJoins

# %%
# last_february_block = get_block_height_for_date('2025-03-01')

# %time ww2_coinjoins = chain.filter_coinjoin_txes(get_block_height_for_date('2024-09-01'),get_block_height_for_date('2024-10-01'), "wasabi2")
# %time ww2_coinjoins = chain.filter_coinjoin_txes(get_block_height_for_date('2024-09-01'),get_block_height_for_date('2024-10-01'), "wasabi1")
# %time ww2_coinjoins = chain.filter_coinjoin_txes(get_block_height_for_date('2024-09-01'),get_block_height_for_date('2024-10-01'), "whirlpool")
# %time ww2_coinjoins = chain.filter_coinjoin_txes(0, len(chain), "wasabi2")
# %time ww1_coinjoins = chain.filter_coinjoin_txes(0, len(chain), "wasabi1")
# %time sw_coinjoins = chain.filter_coinjoin_txes(0, len(chain), "whirlpool")
# %time as_coinjoins = chain.filter_coinjoin_txes(0, len(chain), "ashigaru")

# %time jm_coinjoins = list(chain.filter_coinjoin_txes(0, len(chain), "wasabi2"))

print(len(jm_coinjoins))

# print(len(ww2_coinjoins), len(ww1_coinjoins), len(sw_coinjoins))
# all_coinjoins = set(ww2_coinjoins) | set(ww1_coinjoins) | set(sw_coinjoins)
print(len(jm_coinjoins))
for i in range(2):
    print(jm_coinjoins[i].mempool_space_link)
# Out:
# CPU times: user 1.93 ms, sys: 1.79 ms, total: 3.72 ms
# Wall time: 1.84 ms
# 16
# 16
# https://mempool.space/tx/50f0a89799a4bc5e18b124500e887e630fd10284778dbd27e77ebc3960daba7d
# https://mempool.space/tx/2773395b7756a512f86deff311a082fb6eb19717c5d474b7824703d5cb43d8d9

# %%
print(len(jm_coinjoins))
import json

with open("/mnt/anal/petrs_jm.json", "w") as f:
    f.write(json.dumps([str(x.hash) for x in jm_coinjoins]))
# Out:
# 16

# %%
# %time ww2_consolidations = chain.get_coinjoin_consolidations(0, len(chain), 2, "wasabi2", 1)
# %time ww1_consolidations = chain.get_coinjoin_consolidations(0, len(chain), 2, "wasabi1", 1)
# %time sw_consolidations = chain.get_coinjoin_consolidations(0, len(chain), 2, "whirlpool", 1)
# Out:
# CPU times: user 6.81 ms, sys: 985 µs, total: 7.79 ms
# Wall time: 4.22 ms
# CPU times: user 956 µs, sys: 2.05 ms, total: 3 ms
# Wall time: 1.3 ms
# CPU times: user 772 µs, sys: 971 µs, total: 1.74 ms
# Wall time: 721 µs

# %%
# %time ww2_consolidations_0 = chain.get_coinjoin_consolidations(0, len(chain), 2, "wasabi2", 0)
# %time ww1_consolidations_0 = chain.get_coinjoin_consolidations(0, len(chain), 2, "wasabi1", 0)
# %time sw_consolidations_0 = chain.get_coinjoin_consolidations(0, len(chain), 2, "whirpool", 0)
# Out:
# CPU times: user 9.33 ms, sys: 3.18 ms, total: 12.5 ms
# Wall time: 6.41 ms
# CPU times: user 2.34 ms, sys: 304 µs, total: 2.65 ms
# Wall time: 932 µs
# CPU times: user 0 ns, sys: 1.7 ms, total: 1.7 ms
# Wall time: 856 µs

# %%
print(len(sw_consolidations))

for tx, cs in sw_consolidations:
    certain = cs['certain']
    if len(certain) < 10:
        continue
    print('-' * 30)
    print(tx.mempool_space_link)

    for c in certain:
        print(c, c.mempool_space_link)
        print('*' * 30)
        for i in c.inputs:
            if i.spent_tx == tx:
                print(i.index)
    print("*" * 30)
    break
# Out:
# 0

# %% [markdown]
# ## Number of coinjoins in the wild

# %%
def process_transactions(transactions, label):
    transactions = list(map(lambda tx: {"block_time": tx.block_time}, transactions))
    df = pd.DataFrame(transactions)
    df['block_time'] = pd.to_datetime(df['block_time'])
    df['week'] = df['block_time'].dt.to_period('W').dt.to_timestamp()  # Get the timestamp for the start of the week
    weekly_counts = df.groupby('week').size()
    return weekly_counts, label

weekly_counts_ww2, label_1 = process_transactions(ww2_coinjoins, "Wasabi Wallet 2 CoinJoins")
weekly_counts_ww1, label_2 = process_transactions(ww1_coinjoins, "Wasabi Wallet 1 CoinJoins")
weekly_counts_sw, label_3 = process_transactions(sw_coinjoins, "Samourai Whirlpool CoinJoins")

plt.figure(figsize=(12, 6))

plt.plot(weekly_counts_ww2.index, weekly_counts_ww2.values, label=label_1)
plt.plot(weekly_counts_ww1.index, weekly_counts_ww1.values, label=label_2)
plt.plot(weekly_counts_sw.index, weekly_counts_sw.values, label=label_3)

plt.title("Weekly Transactions Over Time")
plt.xlabel("Time")
plt.ylabel("Number of Transactions")
plt.legend()

plt.grid(True, linestyle='--', linewidth=0.3)
plt.savefig("/mnt/blocksci/weekly_cjs_over_time.png")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 10
#       7     return weekly_counts, label
#       9 weekly_counts_ww2, label_1 = process_transactions(ww2_coinjoins, "Wasabi Wallet 2 CoinJoins")
# ---> 10 weekly_counts_ww1, label_2 = process_transactions(ww1_coinjoins, "Wasabi Wallet 1 CoinJoins")
#      11 weekly_counts_sw, label_3 = process_transactions(sw_coinjoins, "Samourai Whirlpool CoinJoins")
#      13 plt.figure(figsize=(12, 6))
#
# NameError: name 'ww1_coinjoins' is not defined

# %% [markdown]
# ## Liquidity

# %%
tx: blocksci.Tx
i: blocksci.Input
from collections import defaultdict
from datetime import datetime, timedelta

def process_input_liquidity(cjs, label):
    input_liquitidy_per_date = {}
    s = set(cjs)
    
    for tx in cjs:
        tx_date = tx.block_time.date()
        if tx_date not in input_liquitidy_per_date:
            input_liquitidy_per_date[tx_date] = 0
    
        for i in tx.inputs:
            if i.spent_tx in s:
                continue
    
            input_liquitidy_per_date[tx_date] += i.value

    sorted_liquidity = {k: v / 100000000 for k, v in sorted(input_liquitidy_per_date.items(), key=lambda t: t[0]) if k is not None}
    

    return sorted_liquidity, label

liq1, lab1 = process_input_liquidity(ww2_coinjoins, "Wasabi2 Input Liquidity")
liq2, lab2 = process_input_liquidity(ww1_coinjoins, "Wasabi1 Input Liquidity")
liq3, lab3 = process_input_liquidity(sw_coinjoins, "Whirlpool Input Liquidity")
liq4, lab4 = process_input_liquidity(ashigaru_coinjoins, "Ashigaru Input Liquidity")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 27
#      24     return sorted_liquidity, label
#      26 liq1, lab1 = process_input_liquidity(ww2_coinjoins, "Wasabi2 Input Liquidity")
# ---> 27 liq2, lab2 = process_input_liquidity(ww1_coinjoins, "Wasabi1 Input Liquidity")
#      28 liq3, lab3 = process_input_liquidity(sw_coinjoins, "Whirlpool Input Liquidity")
#      29 liq4, lab4 = process_input_liquidity(ashigaru_coinjoins, "Ashigaru Input Liquidity")
#
# NameError: name 'ww1_coinjoins' is not defined

# %%
def group_by_week(data):
    weekly_data = defaultdict(int)
    for date, count in data.items():
        nd = datetime.combine(date, datetime.min.time())
        week_start = nd - timedelta(days=nd.weekday())
        weekly_data[week_start] += count

    for k in weekly_data:
        weekly_data[k] /= 7
    return dict(sorted(weekly_data.items()))

print(set(type(x) for x in liq3))

df_ww2 = pd.DataFrame([{"time": time, "count": count} for time, count in liq1.items()])
df_ww1 = pd.DataFrame([{"time": time, "count": count} for time, count in liq2.items()])
df_sw = pd.DataFrame([{"time": time, "count": count} for time, count in liq3.items()])
df_as = pd.DataFrame([{"time": time, "count": count} for time, count in liq4.items()])
df_ww2['time'] = pd.to_datetime(df_ww2['time'])
df_ww1['time'] = pd.to_datetime(df_ww1['time'])
df_as['time'] = pd.to_datetime(df_as['time'])
df_sw['time'] = pd.to_datetime(df_sw['time'])



df_ww2['week'] = df_ww2['time'].dt.to_period('M').dt.to_timestamp()  # Get the timestamp for the start of the week
df_ww1['week'] = df_ww1['time'].dt.to_period('M').dt.to_timestamp()  # Get the timestamp for the start of the week
df_sw['week'] = df_sw['time'].dt.to_period('M').dt.to_timestamp()  # Get the timestamp for the start of the week
df_as['week'] = df_as['time'].dt.to_period('M').dt.to_timestamp()  # Get the timestamp for the start of the week

df_ww2 = df_ww2.groupby("week")["count"].sum().reset_index()
df_ww1 = df_ww1.groupby("week")["count"].sum().reset_index()
df_sw = df_sw.groupby("week")["count"].sum().reset_index()
df_as = df_as.groupby("week")["count"].sum().reset_index()

plt.figure(figsize=(12, 6))
plt.plot(df_ww2["week"], df_ww2["count"], label="Wasabi Wallet 2")
plt.plot(df_ww1["week"], df_ww1["count"], label="Wasabi Wallet 1")
plt.plot(df_sw["week"], df_sw["count"], label="Samourai Whirlpool")
plt.plot(df_as["week"], df_as["count"], label="Ashigaru Whirlpool")
plt.title("Fresh input liquidity in CoinJoin transactions over time")
plt.xlabel("Date")
plt.ylabel("Input liquidity (BTC)")
plt.legend()
plt.grid(True, ls='--')
plt.savefig("/mnt/blocksci/liquidity_2025_2_inputs.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 12
#       9         weekly_data[k] /= 7
#      10     return dict(sorted(weekly_data.items()))
# ---> 12 print(set(type(x) for x in liq3))
#      14 df_ww2 = pd.DataFrame([{"time": time, "count": count} for time, count in liq1.items()])
#      15 df_ww1 = pd.DataFrame([{"time": time, "count": count} for time, count in liq2.items()])
#
# NameError: name 'liq3' is not defined

# %%
def group_by_week(data):
    weekly_data = defaultdict(int)
    for date, count in data.items():
        nd = datetime.combine(date, datetime.min.time())
        week_start = nd - timedelta(days=nd.weekday())
        weekly_data[week_start] += count

    for k in weekly_data:
        weekly_data[k] /= 7
    return dict(sorted(weekly_data.items()))

print(set(type(x) for x in liq3))

df_ww2 = pd.DataFrame([{"time": time, "count": count} for time, count in liq1.items()])
df_ww1 = pd.DataFrame([{"time": time, "count": count} for time, count in liq2.items()])
df_sw = pd.DataFrame([{"time": time, "count": count} for time, count in liq3.items()])
df_as = pd.DataFrame([{"time": time, "count": count} for time, count in liq4.items()])
df_ww2['time'] = pd.to_datetime(df_ww2['time'])
df_ww1['time'] = pd.to_datetime(df_ww1['time'])
df_as['time'] = pd.to_datetime(df_as['time'])
df_sw['time'] = pd.to_datetime(df_sw['time'])



df_ww2['week'] = df_ww2['time'].dt.to_period('M').dt.to_timestamp()  # Get the timestamp for the start of the week
df_ww1['week'] = df_ww1['time'].dt.to_period('M').dt.to_timestamp()  # Get the timestamp for the start of the week
df_sw['week'] = df_sw['time'].dt.to_period('M').dt.to_timestamp()  # Get the timestamp for the start of the week
df_as['week'] = df_as['time'].dt.to_period('M').dt.to_timestamp()  # Get the timestamp for the start of the week

df_ww2 = df_ww2.groupby("week")["count"].sum().reset_index()
df_ww1 = df_ww1.groupby("week")["count"].sum().reset_index()
df_sw = df_sw.groupby("week")["count"].sum().reset_index()
df_as = df_as.groupby("week")["count"].sum().reset_index()

plt.figure(figsize=(12, 6))
plt.plot(df_ww2["week"], df_ww2["count"], label="Wasabi Wallet 2")
plt.plot(df_ww1["week"], df_ww1["count"], label="Wasabi Wallet 1")
plt.plot(df_sw["week"], df_sw["count"], label="Samourai Whirlpool")
plt.plot(df_as["week"], df_as["count"], label="Ashigaru Whirlpool")
plt.title("Fresh input liquidity in CoinJoin transactions over time")
plt.xlabel("Date")
plt.ylabel("Input liquidity (BTC)")
plt.legend()
plt.grid(True, ls='--')
plt.savefig("/mnt/blocksci/liquidity_2025_2_inputs.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 12
#       9         weekly_data[k] /= 7
#      10     return dict(sorted(weekly_data.items()))
# ---> 12 print(set(type(x) for x in liq3))
#      14 df_ww2 = pd.DataFrame([{"time": time, "count": count} for time, count in liq1.items()])
#      15 df_ww1 = pd.DataFrame([{"time": time, "count": count} for time, count in liq2.items()])
#
# NameError: name 'liq3' is not defined

# %% [markdown]
# ## Traverses

# %%
# %time flows = chain.find_traverses_between_coinjoins(0, len(chain))
# Out:
# CPU times: user 33.5 ms, sys: 4.85 ms, total: 38.3 ms
# Wall time: 34.7 ms

# %%
def cmp(cjt1, cjt2):
    return int(cjt1) < int(cjt2)

blocksci.CoinJoinType.__lt__ = cmp

# %%
import datetime

# flatten and convert to enums
records = []
for dt, from_map in flows.items():
    for from_cj, to_map in from_map.items():
        for to_cj, count in to_map.items():
            time = chain[dt].time
            # non-relevant values before this date
            if time < datetime.datetime(2022, 5, 1):
                continue
            records.append({"datetime": time, "from_cj": str(blocksci.CoinJoinType(from_cj)).split('.')[1], "to_cj": str(blocksci.CoinJoinType(to_cj)).split('.')[1], "count": count})

df = pd.DataFrame(records)
df['datetime'] = pd.to_datetime(df['datetime'])
df['week'] = df['datetime'].dt.to_period('W').apply(lambda x: x.start_time)

unique_weeks = df['week'].unique()
unique_from_cj = df['from_cj'].unique()
unique_to_cj = df['to_cj'].unique()

full_index = pd.MultiIndex.from_product(
    [unique_weeks, unique_from_cj, unique_to_cj],
    names=["week", "from_cj", "to_cj"]
)

df['week'] = df['week'].dt.normalize()
df_full = df.groupby(['week', 'from_cj', 'to_cj'])['count'].sum().reset_index()
df_full = df_full.set_index(["week", "from_cj", "to_cj"]).reindex(full_index, fill_value=0).reset_index()

pivot_df = df_full.pivot_table(
    index="week",
    columns=["from_cj", "to_cj"],
    values="count",
    fill_value=0
)


pivot_df = pivot_df.drop(columns=pivot_df.columns[(pivot_df == 0).all()])
plt.rcParams.update({'font.size': 26})

pivot_df.plot(figsize=(30, 15), logy=True, linewidth=3)
plt.title("Flows between CoinJoin coordinators over weeks")
plt.xlabel("Date")
plt.ylabel("Number of transitions")
plt.legend(title="From -> To", loc="center right", bbox_to_anchor=(1.4, 0.5))
plt.tight_layout()
plt.grid(True)
plt.savefig("/mnt/blocksci/flows-2025-2_input.png")


plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 15
#      12             records.append({"datetime": time, "from_cj": str(blocksci.CoinJoinType(from_cj)).split('.')[1], "to_cj": str(blocksci.CoinJoinType(to_cj)).split('.')[1], "count": count})
#      14 df = pd.DataFrame(records)
# ---> 15 df['datetime'] = pd.to_datetime(df['datetime'])
#      16 df['week'] = df['datetime'].dt.to_period('W').apply(lambda x: x.start_time)
#      18 unique_weeks = df['week'].unique()
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/range.py:349, in RangeIndex.get_loc(self, key)
#     347         raise KeyError(key) from err
#     348 if isinstance(key, Hashable):
# --> 349     raise KeyError(key)
#     350 self._check_indexing_error(key)
#     351 raise KeyError(key)
#
# KeyError: 'datetime'

# %% [markdown]
# ## Anonymity degradation

# %% [markdown]
# ### calculation

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from math import log2, factorial


def plot_anonymity_degradation(original_data, after_day_data, after_week_data, after_month_data, after_year, after_all, tag, subtag=""):
    # the log2(factorial(tx.output_count)) is used to normalize over the output count to compute sort of "percentage"
    # of the available "entropy"
            
    df_original = pd.DataFrame(
        # [(transaction.block_time, count / log2(factorial(transaction.output_count))) for transaction, count in original_data.items()],
        [(transaction.block_time, data["total_count"] / (data["not_remixed_outputs"] or 1) or 1) for transaction, data in original_data.items() if data['total_count'] != 0 and data['not_remixed_outputs'] != 0],
        columns=["block_time", "original_anonymity_score"],
    ) if "ignored" not in tag else pd.DataFrame(
        # [(transaction.block_time, count / log2(factorial(transaction.output_count))) for transaction, count in original_data.items()],
        [(transaction.block_time, data["total_count"] / (data["not_remixed_not_ignored_outputs"] or 1) or 1) for transaction, data in original_data.items() if data['total_count'] != 0 and data['not_remixed_not_ignored_outputs'] != 0],
        columns=["block_time", "original_anonymity_score"],
    )

    df_after_day = pd.DataFrame(
        [(transaction.block_time, data["total_count"] / (data["not_remixed_outputs"] or 1) or 1) for transaction, data in after_day_data.items() if data['total_count'] != 0 and data['not_remixed_outputs'] != 0],
        columns=["block_time", "anonymity_set_after_day"],
    ) if "ignored" not in tag else pd.DataFrame(
        [(transaction.block_time, data["total_count"] / (data["not_remixed_not_ignored_outputs"] or 1) or 1) for transaction, data in after_day_data.items() if data['total_count'] != 0 and data['not_remixed_not_ignored_outputs'] != 0],
        columns=["block_time", "anonymity_set_after_day"],
    ) 
    
    df_after_week = pd.DataFrame(
        [(transaction.block_time, data["total_count"] / (data["not_remixed_outputs"] or 1) or 1) for transaction, data in after_week_data.items() if data['total_count'] != 0 and data['not_remixed_outputs'] != 0],
        columns=["block_time", "anonymity_set_after_week"],
    ) if "ignored" not in tag else pd.DataFrame(
        [(transaction.block_time, data["total_count"] / (data["not_remixed_not_ignored_outputs"] or 1) or 1) for transaction, data in after_week_data.items() if data['total_count'] != 0 and data['not_remixed_not_ignored_outputs'] != 0],
        columns=["block_time", "anonymity_set_after_week"],
    )
    
    df_after_month = pd.DataFrame(
        [(transaction.block_time, data["total_count"] / (data["not_remixed_outputs"] or 1) or 1) for transaction, data in after_month_data.items() if data['total_count'] != 0 and data['not_remixed_outputs'] != 0],
        columns=["block_time", "anonymity_set_after_month"],
    ) if "ignored" not in tag else pd.DataFrame(
        [(transaction.block_time, data["total_count"] / (data["not_remixed_not_ignored_outputs"] or 1) or 1) for transaction, data in after_month_data.items() if data['total_count'] != 0 and data['not_remixed_not_ignored_outputs'] != 0],
        columns=["block_time", "anonymity_set_after_month"],
    )

    df_after_year = pd.DataFrame(
        [(transaction.block_time, data["total_count"] / (data["not_remixed_outputs"] or 1) or 1) for transaction, data in after_year.items() if data['total_count'] != 0 and data['not_remixed_outputs'] != 0],
        columns=["block_time", "anonymity_set_after_year"],
    ) if "ignored" not in tag else pd.DataFrame(
        [(transaction.block_time, data["total_count"] / (data["not_remixed_not_ignored_outputs"] or 1) or 1) for transaction, data in after_year.items() if data['total_count'] != 0 and data['not_remixed_not_ignored_outputs'] != 0],
        columns=["block_time", "anonymity_set_after_year"],
    )

    df_after_all = pd.DataFrame(
        [(transaction.block_time, data["total_count"] / (data["not_remixed_outputs"] or 1) or 1) for transaction, data in after_all.items() if data['total_count'] != 0 and data['not_remixed_outputs'] != 0],
        columns=["block_time", "anonymity_set_after_all"],
    ) if "ignored" not in tag else pd.DataFrame(
        [(transaction.block_time, data["total_count"] / (data["not_remixed_not_ignored_outputs"] or 1) or 1) for transaction, data in after_all.items() if data['total_count'] != 0 and data['not_remixed_not_ignored_outputs'] != 0],
        columns=["block_time", "anonymity_set_after_all"],
    )
    
    df_original["block_time"] = pd.to_datetime(df_original["block_time"])
    df_after_day["block_time"] = pd.to_datetime(df_after_day["block_time"])
    df_after_week["block_time"] = pd.to_datetime(df_after_week["block_time"])
    df_after_month["block_time"] = pd.to_datetime(df_after_month["block_time"])
    df_after_year["block_time"] = pd.to_datetime(df_after_year["block_time"])
    df_after_all["block_time"] = pd.to_datetime(df_after_all["block_time"])
    
    df_original["week_start"] = df_original["block_time"].dt.to_period("W").apply(lambda r: r.start_time)
    df_after_day["week_start"] = df_after_day["block_time"].dt.to_period("W").apply(lambda r: r.start_time)
    df_after_week["week_start"] = df_after_week["block_time"].dt.to_period("W").apply(lambda r: r.start_time)
    df_after_month["week_start"] = df_after_month["block_time"].dt.to_period("W").apply(lambda r: r.start_time)
    df_after_year["week_start"] = df_after_year["block_time"].dt.to_period("W").apply(lambda r: r.start_time)
    df_after_all["week_start"] = df_after_all["block_time"].dt.to_period("W").apply(lambda r: r.start_time)
    
    weekly_original = df_original.groupby("week_start")["original_anonymity_score"].mean().reset_index()
    weekly_after_day = df_after_day.groupby("week_start")["anonymity_set_after_day"].mean().reset_index()
    weekly_after_week = df_after_week.groupby("week_start")["anonymity_set_after_week"].mean().reset_index()
    weekly_after_month = df_after_month.groupby("week_start")["anonymity_set_after_month"].mean().reset_index()
    weekly_after_year = df_after_year.groupby("week_start")["anonymity_set_after_year"].mean().reset_index()
    weekly_after_all = df_after_all.groupby("week_start")["anonymity_set_after_all"].mean().reset_index()
    
    weekly_data = pd.merge(weekly_original, weekly_after_week, on="week_start", how="outer")
    weekly_data = pd.merge(weekly_data, weekly_after_day, on="week_start", how="outer")
    weekly_data = pd.merge(weekly_data, weekly_after_month, on="week_start", how="outer")
    weekly_data = pd.merge(weekly_data, weekly_after_year, on="week_start", how="outer")
    weekly_data = pd.merge(weekly_data, weekly_after_all, on="week_start", how="outer")
    
    plt.rcParams.update({'font.size': 16})
    plt.figure(figsize=(16, 10))
    plt.plot(
        weekly_data["week_start"],
        weekly_data["original_anonymity_score"],
        label="Initial computed anonymity value",
    )
    plt.plot(
        weekly_data["week_start"],
        weekly_data["anonymity_set_after_day"],
        label="Computed anonymity value after 1 day",
        linestyle='dotted'
    )
    plt.plot(
        weekly_data["week_start"],
        weekly_data["anonymity_set_after_week"],
        label="Computed anonymity value after 7 days",
        linestyle='dashed',
    )
    plt.plot(
        weekly_data["week_start"],
        weekly_data["anonymity_set_after_month"],
        label="Computed anonymity value after 31 days",
        linewidth=1,
        linestyle='dashdot'
    )
    plt.plot(
        weekly_data["week_start"],
        weekly_data["anonymity_set_after_year"],
        label="Computed anonymity value after 365 days",
        linestyle='dotted'
    )

    plt.plot(
        weekly_data["week_start"],
        weekly_data["anonymity_set_after_all"],
        label="Computed anonymity value with no time limit",
        linestyle='dashed'
    )
    
    plt.xlabel("Week")
    plt.ylabel("Percentage of unconsolidated outputs")
    plt.title(f"Percentage of unconsolidated outputs for {tag.split('_')[0].upper()}{'_' + subtag if subtag else ''} CoinJoins")
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.ylim(ymin=0)
    plt.legend()
    plt.tight_layout()
    plt.savefig(f"/mnt/blocksci/anonymity_degradation_no_remixes_{tag}{'_' + subtag if subtag else ''}_20_input_correct.png")
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from math import log2, factorial

def compute_and_plot_differences(original_data, after_day_data, after_week_data, after_month_data, after_year_data, tag, subtag=""):
    def make_df(data, col_name):
        df = pd.DataFrame(
            # [(tx.block_time, val / log2(factorial(tx.output_count))) for tx, val in data.items()],
            [(tx.block_time, data["total_count"] / tx.output_count]) for tx, data in data.items()],
            columns=["block_time", col_name],
        )
        df["block_time"] = pd.to_datetime(df["block_time"])
        df["week_start"] = df["block_time"].dt.to_period("M").apply(lambda r: r.start_time)
        return df

    df_original = make_df(original_data, "original_value")
    df_after_day = make_df(after_day_data, "after_day_value")
    df_after_week = make_df(after_week_data, "after_week_value")
    df_after_month = make_df(after_month_data, "after_month_value")
    df_after_year = make_df(after_year_data, "after_year_value")

    df_original = df_original.groupby("week_start")["original_value"].mean().reset_index()
    df_after_day = df_after_day.groupby("week_start")["after_day_value"].mean().reset_index()
    df_after_week = df_after_week.groupby("week_start")["after_week_value"].mean().reset_index()
    df_after_month = df_after_month.groupby("week_start")["after_month_value"].mean().reset_index()
    df_after_year = df_after_year.groupby("week_start")["after_year_value"].mean().reset_index()

    merged = df_original.merge(df_after_day, on="week_start", how="outer")
    merged = merged.merge(df_after_week, on="week_start", how="outer")
    merged = merged.merge(df_after_month, on="week_start", how="outer")
    merged = merged.merge(df_after_year, on="week_start", how="outer")

    merged["diff_0_1d"] = abs(merged["after_day_value"] - merged["original_value"])
    merged["diff_1d_7d"] = abs(merged["after_week_value"] - merged["after_day_value"])
    merged["diff_7d_31d"] = abs(merged["after_month_value"] - merged["after_week_value"])
    merged["diff_31d_365d"] = abs(merged["after_year_value"] - merged["after_month_value"])

    plt.rcParams.update({'font.size': 16})
    plt.figure(figsize=(16,6))
    plt.plot(merged["week_start"], merged["diff_0_1d"], label="Difference (0–1d)")
    plt.plot(merged["week_start"], merged["diff_1d_7d"], label="Difference (1d–7d)", ls='--')
    plt.plot(merged["week_start"], merged["diff_7d_31d"], label="Difference (7d–31d)", ls=':')
    plt.plot(merged["week_start"], merged["diff_31d_365d"], label="Difference (31d–365d)", ls='-.')

    plt.xlabel("Month")
    plt.ylabel("Difference in anonymity values")
    plt.title(f"Differences (0–1d, 1d–7d, 7d–31d, 31d-365d) for {tag.split('_')[0].upper()}{'_' + subtag if subtag else ''} CoinJoins")
    plt.xticks(rotation=45)
    plt.legend()
    plt.tight_layout()
    plt.grid(True)
    plt.savefig(f"/mnt/blocksci/anonymity_degradation_differences_{tag}{'_' + subtag if subtag else ''}_all.png")
    plt.show()
    
    print("original mean", merged["original_value"].mean())
    print("after day", merged["after_day_value"].mean())
    print("after week", merged["after_week_value"].mean())
    print("after month", merged["after_month_value"].mean())
    print("after year", merged["after_year_value"].mean())


def compute_and_plot_quartiles(after_day_data, after_year_data, tag, subtag=""):
    def make_df(data, col_name):
        df = pd.DataFrame(
            # [(tx.block_time, val / log2(factorial(tx.output_count))) for tx, val in data.items()],
            [(tx.block_time, val / tx.output_count) for tx, (_, val) in data.items()],
            columns=["block_time", col_name],
        )
        df["block_time"] = pd.to_datetime(df["block_time"])
        df["week_start"] = df["block_time"].dt.to_period("W").apply(lambda r: r.start_time)
        return df

    df_after_day = make_df(after_day_data, "after_day_value")
    df_after_year = make_df(after_year_data, "after_year_value")

    merged = pd.merge(df_after_day, df_after_year, on=["block_time","week_start"], how="outer")

    weekly = merged.groupby("week_start").agg({
        "after_day_value": ['mean', lambda x: x.quantile(0.25), 'median', lambda x: x.quantile(0.75)],
        "after_year_value": ['mean', lambda x: x.quantile(0.25), 'median', lambda x: x.quantile(0.75)],
    }).reset_index()

    weekly.columns = [
        "week_start",
        "after_day_mean", "after_day_q1", "after_day_median", "after_day_q3",
        "after_year_mean", "after_year_q1", "after_year_median", "after_year_q3"
    ]
    
    plt.rcParams.update({'font.size': 16})
    plt.figure(figsize=(16, 10))
    plt.plot(weekly["week_start"], weekly["after_day_mean"], label="After 1 day (mean)", color='blue')
    plt.fill_between(weekly["week_start"], weekly["after_day_q1"], weekly["after_day_q3"], color='blue', alpha=0.2, label="1 day (Q1–Q3)")

    plt.plot(weekly["week_start"], weekly["after_year_mean"], label="After 1 year (mean)", color='red')
    plt.fill_between(weekly["week_start"], weekly["after_year_q1"], weekly["after_year_q3"], color='red', alpha=0.2, label="1 year (Q1–Q3)")
    
    plt.xlabel("Week")
    plt.ylabel("Computed anonymity value")
    plt.title(f"After 1 day and 1 year anonymity values with quartiles for {tag.split('_')[0].upper()}{'_' + subtag if subtag else ''} CoinJoins")
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.savefig(f"/mnt/blocksci/anonymity_degradation_quartiles_{tag}{'_' + subtag if subtag else ''}_new.png")
    plt.show()
# Out:
#   Cell In[19], line 9
#     [(tx.block_time, data["total_count"] / tx.output_count]) for tx, data in data.items()],
#                                                           ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %% [markdown]
# ### results

# %%
# %time ww1_original_data = chain.compute_anonymity_degradation(0, len(chain), 0, "wasabi1")
# %time ww1_after_day_data = chain.compute_anonymity_degradation(0, len(chain), 1, "wasabi1")
# %time ww1_after_week_data = chain.compute_anonymity_degradation(0, len(chain), 7, "wasabi1")
# %time ww1_after_month_data = chain.compute_anonymity_degradation(0, len(chain), 31, "wasabi1")
# %time ww1_after_year_data = chain.compute_anonymity_degradation(0, len(chain), 365, "wasabi1")
# %time ww1_after_full_data = chain.compute_anonymity_degradation(0, len(chain), 365*7, "wasabi1")

# %time ww2_original_data = chain.compute_anonymity_degradation(0, len(chain), 0, "wasabi2")
# %time ww2_after_day_data = chain.compute_anonymity_degradation(0, len(chain), 1, "wasabi2")
# %time ww2_after_week_data = chain.compute_anonymity_degradation(0, len(chain), 7, "wasabi2")
# %time ww2_after_month_data = chain.compute_anonymity_degradation(0, len(chain), 31, "wasabi2")
# %time ww2_after_year_data = chain.compute_anonymity_degradation(0, len(chain), 365, "wasabi2")
# %time ww2_after_full_data = chain.compute_anonymity_degradation(0, len(chain), 365*7, "wasabi2")


# %time sw_original_data = chain.compute_anonymity_degradation(0, len(chain), 0, "whirlpool")
# %time sw_after_day_data = chain.compute_anonymity_degradation(0, len(chain), 1, "whirlpool")
# %time sw_after_week_data = chain.compute_anonymity_degradation(0, len(chain), 7, "whirlpool")
# %time sw_after_month_data = chain.compute_anonymity_degradation(0, len(chain), 31, "whirlpool")
# %time sw_after_year_data = chain.compute_anonymity_degradation(0, len(chain), 365, "whirlpool")
# %time sw_after_full_data = chain.compute_anonymity_degradation(0, len(chain), 365*7, "whirlpool")

# %time sw_original_data_50m = chain.compute_anonymity_degradation(0, len(chain), 0, "whirlpool", "50m")
# %time sw_after_day_data_50m = chain.compute_anonymity_degradation(0, len(chain), 1, "whirlpool", "50m")
# %time sw_after_week_data_50m = chain.compute_anonymity_degradation(0, len(chain), 7, "whirlpool", "50m")
# %time sw_after_month_data_50m = chain.compute_anonymity_degradation(0, len(chain), 31, "whirlpool", "50m")
# %time sw_after_year_data_50m = chain.compute_anonymity_degradation(0, len(chain), 365, "whirlpool", "50m")
# %time sw_after_full_data_50m = chain.compute_anonymity_degradation(0, len(chain), 365*7, "whirlpool", "50m")

# %time sw_original_data_5m = chain.compute_anonymity_degradation(0, len(chain), 0, "whirlpool", "5m")
# %time sw_after_day_data_5m = chain.compute_anonymity_degradation(0, len(chain), 1, "whirlpool", "5m")
# %time sw_after_week_data_5m = chain.compute_anonymity_degradation(0, len(chain), 7, "whirlpool", "5m")
# %time sw_after_month_data_5m = chain.compute_anonymity_degradation(0, len(chain), 31, "whirlpool", "5m")
# %time sw_after_year_data_5m = chain.compute_anonymity_degradation(0, len(chain), 365, "whirlpool", "5m")
# %time sw_after_full_data_5m = chain.compute_anonymity_degradation(0, len(chain), 365*7, "whirlpool", "5m")


# %time sw_original_data_1m = chain.compute_anonymity_degradation(0, len(chain), 0, "whirlpool", "1m")
# %time sw_after_day_data_1m = chain.compute_anonymity_degradation(0, len(chain), 1, "whirlpool", "1m")
# %time sw_after_week_data_1m = chain.compute_anonymity_degradation(0, len(chain), 7, "whirlpool", "1m")
# %time sw_after_month_data_1m = chain.compute_anonymity_degradation(0, len(chain), 31, "whirlpool", "1m")
# %time sw_after_year_data_1m = chain.compute_anonymity_degradation(0, len(chain), 365, "whirlpool", "1m")
# %time sw_after_full_data_1m = chain.compute_anonymity_degradation(0, len(chain), 365*7, "whirlpool", "1m")

# %time sw_original_data_100k = chain.compute_anonymity_degradation(0, len(chain), 0, "whirlpool", "100k")
# %time sw_after_day_data_100k = chain.compute_anonymity_degradation(0, len(chain), 1, "whirlpool", "100k")
# %time sw_after_week_data_100k = chain.compute_anonymity_degradation(0, len(chain), 7, "whirlpool", "100k")
# %time sw_after_month_data_100k = chain.compute_anonymity_degradation(0, len(chain), 31, "whirlpool", "100k")
# %time sw_after_year_data_100k = chain.compute_anonymity_degradation(0, len(chain), 365, "whirlpool", "100k")
# %time sw_after_full_data_100k = chain.compute_anonymity_degradation(0, len(chain), 365*7, "whirlpool", "100k")
# Out:
# CPU times: user 2.76 ms, sys: 4.05 ms, total: 6.8 ms
# Wall time: 3.3 ms
# CPU times: user 2.05 ms, sys: 2.36 ms, total: 4.42 ms
# Wall time: 1.8 ms
# CPU times: user 2.63 ms, sys: 1.48 ms, total: 4.1 ms
# Wall time: 1.69 ms
# CPU times: user 0 ns, sys: 3.74 ms, total: 3.74 ms
# Wall time: 1.66 ms
# CPU times: user 557 µs, sys: 3 ms, total: 3.56 ms
# Wall time: 1.54 ms
# CPU times: user 3.87 ms, sys: 437 µs, total: 4.3 ms
# Wall time: 1.89 ms
# CPU times: user 1.64 ms, sys: 2.29 ms, total: 3.93 ms
# Wall time: 1.8 ms
# CPU times: user 2.63 ms, sys: 1.48 ms, total: 4.12 ms
# Wall time: 1.59 ms
# CPU times: user 1.59 ms, sys: 2.26 ms, total: 3.86 ms
# Wall time: 1.54 ms
# CPU times: user 2.96 ms, sys: 1.03 ms, total: 3.99 ms
# Wall time: 1.74 ms
# CPU times: user 0 ns, sys: 3.05 ms, total: 3.05 ms
# Wall time: 1.3 ms
# CPU times: user 1.55 ms, sys: 1.32 ms, total: 2.87 ms
# Wall time: 1.1 ms
# CPU times: user 0 ns, sys: 2.17 ms, total: 2.17 ms
# Wall time: 848 µs
# CPU times: user 133 µs, sys: 2.68 ms, total: 2.81 ms
# Wall time: 1.12 ms
# CPU times: user 0 ns, sys: 3.25 ms, total: 3.25 ms
# Wall time: 1.19 ms
# CPU times: user 321 µs, sys: 2.66 ms, total: 2.99 ms
# Wall time: 1.19 ms
# CPU times: user 0 ns, sys: 3.03 ms, total: 3.03 ms
# Wall time: 1.1 ms
# CPU times: user 954 µs, sys: 2.09 ms, total: 3.04 ms
# Wall time: 1.38 ms
# CPU times: user 1.78 ms, sys: 1.36 ms, total: 3.13 ms
# Wall time: 1.3 ms
# CPU times: user 2.64 ms, sys: 1.36 ms, total: 3.99 ms
# Wall time: 1.72 ms
# CPU times: user 2.45 ms, sys: 1.33 ms, total: 3.77 ms
# Wall time: 1.6 ms
# CPU times: user 995 µs, sys: 3.03 ms, total: 4.03 ms
# Wall time: 1.82 ms
# CPU times: user 802 µs, sys: 3.35 ms, total: 4.15 ms
# Wall time: 1.78 ms
# CPU times: user 430 µs, sys: 3.11 ms, total: 3.54 ms
# Wall time: 1.31 ms
# CPU times: user 625 µs, sys: 2.07 ms, total: 2.7 ms
# Wall time: 1.07 ms
# CPU times: user 1.6 ms, sys: 1.88 ms, total: 3.48 ms
# Wall time: 1.33 ms
# CPU times: user 1.88 ms, sys: 1.38 ms, total: 3.26 ms
# Wall time: 1.38 ms
# CPU times: user 989 µs, sys: 2.13 ms, total: 3.12 ms
# Wall time: 1.31 ms
# CPU times: user 611 µs, sys: 2.25 ms, total: 2.86 ms
# Wall time: 1.22 ms
# CPU times: user 1.74 ms, sys: 2.26 ms, total: 4 ms
# Wall time: 1.64 ms
# CPU times: user 0 ns, sys: 2.94 ms, total: 2.94 ms
# Wall time: 1.19 ms
# CPU times: user 1.46 ms, sys: 2.49 ms, total: 3.94 ms
# Wall time: 1.87 ms
# CPU times: user 2.46 ms, sys: 1.31 ms, total: 3.77 ms
# Wall time: 1.57 ms
# CPU times: user 1.66 ms, sys: 2.07 ms, total: 3.73 ms
# Wall time: 1.47 ms
# CPU times: user 2.01 ms, sys: 1.05 ms, total: 3.06 ms
# Wall time: 1.24 ms
# CPU times: user 1.87 ms, sys: 1.03 ms, total: 2.9 ms
# Wall time: 1.21 ms
# CPU times: user 380 µs, sys: 2.03 ms, total: 2.41 ms
# Wall time: 1.1 ms
# CPU times: user 679 µs, sys: 2.97 ms, total: 3.65 ms
# Wall time: 1.6 ms
# CPU times: user 1.92 ms, sys: 1.22 ms, total: 3.14 ms
# Wall time: 1.22 ms
# CPU times: user 2.82 ms, sys: 293 µs, total: 3.11 ms
# Wall time: 1.27 ms
# CPU times: user 1.03 ms, sys: 2.14 ms, total: 3.17 ms
# Wall time: 1.31 ms
# CPU times: user 0 ns, sys: 3.52 ms, total: 3.52 ms
# Wall time: 1.7 ms

# %%
plot_anonymity_degradation(ww1_original_data, ww1_after_day_data, ww1_after_week_data, ww1_after_month_data, ww1_after_year_data, ww1_after_full_data, "ww1_multiple_txes")
# compute_and_plot_quartiles(ww1_after_day_data, ww1_after_year_data, "ww1_cjs")
# compute_and_plot_differences(ww1_original_data, ww1_after_day_data, ww1_after_week_data, ww1_after_month_data, ww1_after_year_data, "ww1_multiple_txes")

plot_anonymity_degradation(ww2_original_data, ww2_after_day_data, ww2_after_week_data, ww2_after_month_data, ww2_after_year_data, ww2_after_full_data, "ww2_multiple_txes")
# compute_and_plot_differences(ww2_original_data, ww2_after_day_data, ww2_after_week_data, ww2_after_month_data, ww2_after_year_data, "ww2_multiple_txes")
# compute_and_plot_quartiles(ww2_after_day_data, ww2_after_year_data, "ww2_cjs")

plot_anonymity_degradation(sw_original_data, sw_after_day_data, sw_after_week_data, sw_after_month_data, sw_after_year_data, sw_after_full_data, "sw_multiple_txes")
# compute_and_plot_differences(sw_original_data, sw_after_day_data, sw_after_week_data, sw_after_month_data, sw_after_year_data, "sw_multiple_txes")
# compute_and_plot_quartiles(sw_after_day_data, sw_after_year_data, "sw_cjs")

plot_anonymity_degradation(sw_original_data_50m, sw_after_day_data_50m, sw_after_week_data_50m, sw_after_month_data_50m, sw_after_year_data_50m, sw_after_full_data_50m, "sw_multiple_txes", "50m")
# compute_and_plot_differences(sw_original_data_50m, sw_after_day_data_50m, sw_after_week_data_50m, sw_after_month_data_50m, sw_after_year_data_50m, "sw_multiple_txes", "50m")
# compute_and_plot_quartiles(sw_after_day_data_50m, sw_after_year_data_50m, "sw_cjs", "50m")

plot_anonymity_degradation(sw_original_data_5m, sw_after_day_data_5m, sw_after_week_data_5m, sw_after_month_data_5m, sw_after_year_data_5m, sw_after_full_data_5m, "sw_multiple_txes", "5m")
# compute_and_plot_differences(sw_original_data_5m, sw_after_day_data_5m, sw_after_week_data_5m, sw_after_month_data_5m, sw_after_year_data_5m, "sw_multiple_txes", "5m")
# compute_and_plot_quartiles(sw_after_day_data_5m, sw_after_year_data_5m, "sw_cjs", "5m")


plot_anonymity_degradation(sw_original_data_1m, sw_after_day_data_1m, sw_after_week_data_1m, sw_after_month_data_1m, sw_after_year_data_1m, sw_after_full_data_1m, "sw_multiple_txes", "1m")
# compute_and_plot_differences(sw_original_data_1m, sw_after_day_data_1m, sw_after_week_data_1m, sw_after_month_data_1m, sw_after_year_data_1m, "sw_multiple_txes", "1m")
# compute_and_plot_quartiles(sw_after_day_data_1m, sw_after_year_data_1m, "sw_cjs", "1m")


plot_anonymity_degradation(sw_original_data_100k, sw_after_day_data_100k, sw_after_week_data_100k, sw_after_month_data_100k, sw_after_year_data_100k, sw_after_full_data_100k, "sw_multiple_txes", "100k")
# compute_and_plot_differences(sw_original_data_100k, sw_after_day_data_100k, sw_after_week_data_100k, sw_after_month_data_100k, sw_after_year_data_100k, "sw_multiple_txes", "100k")
# compute_and_plot_quartiles(sw_after_day_data_100k, sw_after_year_data_100k, "sw_cjs", "100k")

# %%
# %time ww1_ign_original_data = chain.compute_anonymity_degradation(0, len(chain), 0, "wasabi1", ignoreNonStandardDenominations=True)
# %time ww1_ign_after_day_data = chain.compute_anonymity_degradation(0, len(chain), 1, "wasabi1", ignoreNonStandardDenominations=True)
# %time ww1_ign_after_week_data = chain.compute_anonymity_degradation(0, len(chain), 7, "wasabi1", ignoreNonStandardDenominations=True)
# %time ww1_ign_after_month_data = chain.compute_anonymity_degradation(0, len(chain), 31, "wasabi1", ignoreNonStandardDenominations=True)
# %time ww1_ign_after_year_data = chain.compute_anonymity_degradation(0, len(chain), 365, "wasabi1", ignoreNonStandardDenominations=True)
# %time ww1_ign_after_full_data = chain.compute_anonymity_degradation(0, len(chain), 365*7, "wasabi1", ignoreNonStandardDenominations=True)

# %time ww2_ign_original_data = chain.compute_anonymity_degradation(0, len(chain), 0, "wasabi2", ignoreNonStandardDenominations=True)
# %time ww2_ign_after_day_data = chain.compute_anonymity_degradation(0, len(chain), 1, "wasabi2", ignoreNonStandardDenominations=True)
# %time ww2_ign_after_week_data = chain.compute_anonymity_degradation(0, len(chain), 7, "wasabi2", ignoreNonStandardDenominations=True)
# %time ww2_ign_after_month_data = chain.compute_anonymity_degradation(0, len(chain), 31, "wasabi2", ignoreNonStandardDenominations=True)
# %time ww2_ign_after_year_data = chain.compute_anonymity_degradation(0, len(chain), 365, "wasabi2", ignoreNonStandardDenominations=True)
# %time ww2_ign_after_full_data = chain.compute_anonymity_degradation(0, len(chain), 365*7, "wasabi2", ignoreNonStandardDenominations=True)
# Out:
# CPU times: user 500 µs, sys: 5.13 ms, total: 5.63 ms
# Wall time: 2.76 ms
# CPU times: user 0 ns, sys: 3.92 ms, total: 3.92 ms
# Wall time: 1.84 ms
# CPU times: user 0 ns, sys: 3.57 ms, total: 3.57 ms
# Wall time: 1.4 ms
# CPU times: user 1.51 ms, sys: 2.12 ms, total: 3.63 ms
# Wall time: 1.52 ms
# CPU times: user 3.06 ms, sys: 1.41 ms, total: 4.46 ms
# Wall time: 2.01 ms
# CPU times: user 331 µs, sys: 4.11 ms, total: 4.44 ms
# Wall time: 1.97 ms
# CPU times: user 1.53 ms, sys: 1.94 ms, total: 3.47 ms
# Wall time: 1.53 ms
# CPU times: user 0 ns, sys: 4.01 ms, total: 4.01 ms
# Wall time: 1.94 ms
# CPU times: user 1.82 ms, sys: 12.6 ms, total: 14.4 ms
# Wall time: 4.16 ms
# CPU times: user 1.24 ms, sys: 2.26 ms, total: 3.51 ms
# Wall time: 1.4 ms
# CPU times: user 2.64 ms, sys: 1.27 ms, total: 3.92 ms
# Wall time: 1.74 ms
# CPU times: user 2.65 ms, sys: 1.29 ms, total: 3.93 ms
# Wall time: 1.63 ms

# %%
plot_anonymity_degradation(ww1_ign_original_data, ww1_ign_after_day_data, ww1_ign_after_week_data, ww1_ign_after_month_data, ww1_ign_after_year_data, ww1_ign_after_full_data, "ww1_multiple_txes_ignored", "ignored_without_remixes")

plot_anonymity_degradation(ww2_ign_original_data, ww2_ign_after_day_data, ww2_ign_after_week_data, ww2_ign_after_month_data, ww2_ign_after_year_data, ww2_ign_after_full_data, "ww2_multiple_txes_ignored", "ignored_without_remixes")
# compute_and_plot_quartiles(ww1_after_day_data, ww1_after_year_data, "ww1_cjs")
# compute_and_plot_differences(ww1_original_data, ww1_after_day_data, ww1_after_week_data, ww1_after_month_data, ww1_after_year_data, "ww1_multiple_txes")

# %% [markdown]
# # Bybit addresses crusade

# %%
import json
with open("/mnt/anal/wasabi2_kruw_events_22-27.json", "r") as f:
    kruw_data = json.load(f)

# kruw_data["f3c6822ddf648f7fe607c6b108d22473404a1cdb1e26b647dafef5d7e70e8075"] = None
# kruw_data = {"0e173a4203b7d6a42b5a490c852c29431eca5d85ff6ea60462571892eefe5aac": None}

kruw_txes = set(chain.tx_with_hash(h) for h in kruw_data)
print(len(kruw_txes))

# %%
import requests

bybit_data = requests.get("https://hackscan.hackbounty.io/public/hack-address.json").json()
bybit_btc_addresses = set()
for a in bybit_data['0221']['btc']:
    try:
        address = chain.address_from_string(a)
        if address is None:
            continue
        bybit_btc_addresses.add(address)
    except Exception as e:
        print(e)
        print(a)

# %%
a = chain.address_from_string("bc1q533d9nuatdz8j926x9ezmsugv2hu82d3hypzda")
print(a in bybit_btc_addresses)

# %%
for address in bybit_btc_addresses:
    if not isinstance(address, blocksci.Address):
        print(address)

# %time distances = chain.find_kruw_paths_to_bybit(start=get_block_height_for_date("2025-03-10"), stop=len(chain), kruw_tx_ids=kruw_txes, bybit_addresses=bybit_btc_addresses, max_hops=9)

# %%
print(len(distances))
# {
#     "hits": {
#         "adresa_do_které_se_dá_dostat": [
#             {
#                 "txid": "b3fd422d2f3638183a7aececc205b8fcb02da629de4a956aa218199dbc741e96", //coinjoin
#                 "input_index": "78",
#                 "value": 1462644,
#                 "broadcast_time": "2025-02-25 14:32:46.000",
#                 "hops": 5,
#                 "parent_address": ...,
#                 "path": ["parrent_address",...,"this_address"]
#             }
#         ],
# }

result = {}
tx: blocksci.Tx
address: blocksci.Address
max_value = 0
import json
for tx in distances:
    imm = distances[tx]
    for address in imm:
        paths = distances[tx][address]
        for path in paths:
            if str(address) not in result:
                result[str(address)] = []
            last_tx = chain.tx_with_hash(path[0])
            result[str(address)].append({
                "txid_coinjoin": str(tx.hash),
                "txid": str(last_tx.hash),
                "value": last_tx.output_value,
                "broadcast_time_coinjoin": tx.block_time.isoformat(),
                "broadcast_time": last_tx.block_time.isoformat(),
                "path": path,
            })
            if last_tx.output_value > max_value:
                max_value = last_tx.output_value

with open("/mnt/blocksci/results/bybit_kruw_20_input.json", "w") as f:
    f.write(json.dumps(result, indent=4))

print(max_value / 100000000)

# %%
tx = chain.tx_with_hash("97df6540fba1af22bc69a4604ae22351ea71a9d19b803e5fce4b6cca37450cde")
# print(tx.is_ww2_cj_debug)
path = ["25e6a61f86bb49ad2f8b65f80e15fccd99a24448eca3f4ac35b84e7828c2598e", "f112482ddb0aabd8bf5e44cd33ff9588f6d741b7e1305ec0526ee069b7da561d", "e66d9ac49856f176801ebfe5ec775571aa640a7713f187de17a5d2dc3d9d9bff" ]
path = list(map(lambda t: chain.tx_with_hash(t), path))
for tx in path:
    print(tx.hash)
    print(tx.is_ww2_cj_debug)
